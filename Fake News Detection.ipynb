# %% [markdown]
# #                          Fake News Detection

# %% [markdown]
# Project Flow:
#    1: Bussiness Problem
#    2: Data Gathering
#    3: Data Analysis or understanding of a data
#    4: Data Preprocessing:
#       A: Text Cleaning
#       B: Tokenization
#       C: Removal Of Stopwords
#       D: Lemmatization
#
#   5: Vectorization (Convert Text Data into Vector):
#      * TF-IDF
#   6: Model Building:
#      A: Train Test Split
#      B: Model object Initialization
#      C: Model Prediction
#   7: Model Evaluation:
#      A: Accuracy_Score
#      B: Confusion Matrix
#   8: Model Deployment
#   9: Prediction on client data.

# %% [markdown]
# ## Required Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import re
import string
import nltk
from nltk.corpus import stopwords 
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.tokenize import word_tokenize
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
from nltk.stem import WordNetLemmatizer
from collections import Counter
from nltk.util import ngrams
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from  sklearn.tree import DecisionTreeClassifier

# %% [markdown]
#  ## Data Gathering

# %%
fake_df = pd.read_csv('Fake.csv', encoding='latin-1')
fake_df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obamas Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
try:
    true_df = pd.read_csv('True.csv', encoding='latin-1', error_bad_lines=False)
    true_df.head()
except pd.errors.ParserError as e:
    print("ParserError:", e)
# Out:
# C:\Users\Gujar\AppData\Local\Temp\ipykernel_5288\3270545664.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   true_df = pd.read_csv('True.csv', encoding='latin-1', error_bad_lines=False)
# b'Skipping line 11067: expected 4 fields, saw 8\n'

# %%
true_df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %% [markdown]
# ## Data Analysis

# %%
true_df["text"][0]
# Out:
# 'WASHINGTON (Reuters) - The head of a conservative Republican faction in the U.S. Congress, who voted this month for a huge expansion of the national debt to pay for tax cuts, called himself a \x1cfiscal conservative\x1d on Sunday and urged budget restraint in 2018. In keeping with a sharp pivot under way among Republicans, U.S. Representative Mark Meadows, speaking on CBS\x19 \x1cFace the Nation,\x1d drew a hard line on federal spending, which lawmakers are bracing to do battle over in January. When they return from the holidays on Wednesday, lawmakers will begin trying to pass a federal budget in a fight likely to be linked to other issues, such as immigration policy, even as the November congressional election campaigns approach in which Republicans will seek to keep control of Congress. President Donald Trump and his Republicans want a big budget increase in military spending, while Democrats also want proportional increases for non-defense \x1cdiscretionary\x1d spending on programs that support education, scientific research, infrastructure, public health and environmental protection. \x1cThe (Trump) administration has already been willing to say: \x18We\x19re going to increase non-defense discretionary spending ... by about 7 percent,\x19\x1d Meadows, chairman of the small but influential House Freedom Caucus, said on the program. \x1cNow, Democrats are saying that\x19s not enough, we need to give the government a pay raise of 10 to 11 percent. For a fiscal conservative, I don\x19t see where the rationale is. ... Eventually you run out of other people\x19s money,\x1d he said. Meadows was among Republicans who voted in late December for their party\x19s debt-financed tax overhaul, which is expected to balloon the federal budget deficit and add about $1.5 trillion over 10 years to the $20 trillion national debt. \x1cIt\x19s interesting to hear Mark talk about fiscal responsibility,\x1d Democratic U.S. Representative Joseph Crowley said on CBS. Crowley said the Republican tax bill would require the  United States to borrow $1.5 trillion, to be paid off by future generations, to finance tax cuts for corporations and the rich. \x1cThis is one of the least ... fiscally responsible bills we\x19ve ever seen passed in the history of the House of Representatives. I think we\x19re going to be paying for this for many, many years to come,\x1d Crowley said. Republicans insist the tax package, the biggest U.S. tax overhaul in more than 30 years,  will boost the economy and job growth. House Speaker Paul Ryan, who also supported the tax bill, recently went further than Meadows, making clear in a radio interview that welfare or \x1centitlement reform,\x1d as the party often calls it, would be a top Republican priority in 2018. In Republican parlance, \x1centitlement\x1d programs mean food stamps, housing assistance, Medicare and Medicaid health insurance for the elderly, poor and disabled, as well as other programs created by Washington to assist the needy. Democrats seized on Ryan\x19s early December remarks, saying they showed Republicans would try to pay for their tax overhaul by seeking spending cuts for social programs. But the goals of House Republicans may have to take a back seat to the Senate, where the votes of some Democrats will be needed to approve a budget and prevent a government shutdown. Democrats will use their leverage in the Senate, which Republicans narrowly control, to defend both discretionary non-defense programs and social spending, while tackling the issue of the \x1cDreamers,\x1d people brought illegally to the country as children. Trump in September put a March 2018 expiration date on the Deferred Action for Childhood Arrivals, or DACA, program, which protects the young immigrants from deportation and provides them with work permits. The president has said in recent Twitter messages he wants funding for his proposed Mexican border wall and other immigration law changes in exchange for agreeing to help the Dre ...

# %%
fake_df.shape , true_df.shape
# Out:
# ((23481, 4), (21416, 4))

# %%
fake_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB

# %%
true_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21416 entries, 0 to 21415
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21416 non-null  object
#  1   text     21416 non-null  object
#  2   subject  21416 non-null  object
#  3   date     21416 non-null  object
# dtypes: object(4)
# memory usage: 669.4+ KB

# %%
fake_df[fake_df.duplicated()]
# Out:
#                                                    title  \
# 9942   HILLARY TWEETS MESSAGE In Defense Of DACA&OOPS...
# 11446  FORMER DEMOCRAT WARNS Young Americans:
# Rioter...
# 14925  [VIDEO] #BlackLivesMatter Terrorists Storm Dar...
#
#                                                     text   subject  \
# 9942   No time to waste   we've got to fight with eve...  politics
# 11446   Who is silencing political speech, physically...  politics
# 14925  They were probably just looking for a  safe sp...  politics
#
#                date
# 9942    Sep 9, 2017
# 11446  Mar 10, 2017
# 14925  Nov 16, 2015

# %%
fake_df= fake_df.drop_duplicates()

# %%
fake_df.shape
# Out:
# (23478, 4)

# %%
true_df[true_df.duplicated()]
# Out:
#                                                    title  \
# 445    Senate tax bill stalls on deficit-focused 'tri...
# 778    Trump warns 'rogue regime' North Korea of grav...
# 892    Republicans unveil tax cut bill, but the hard ...
# 896    Trump taps Fed centrist Powell to lead U.S. ce...
# 974    Two ex-Trump aides charged in Russia probe, th...
# ...                                                  ...
# 21227  France unveils labor reforms in first step to ...
# 21262  Guatemala top court sides with U.N. graft unit...
# 21289  Europeans, Africans agree renewed push to tack...
# 21352  Thailand's ousted PM Yingluck has fled abroad:...
# 21407  U.S., North Korea clash at U.N. forum over nuc...
#
#                                                     text       subject  \
# 445    WASHINGTON (Reuters) - The U.S. Senate on Thur...  politicsNews
# 778    BEIJING (Reuters) - U.S. President Donald Trum...  politicsNews
# 892    WASHINGTON (Reuters) - U.S. House of Represent...  politicsNews
# 896    WASHINGTON (Reuters) - President Donald Trump ...  politicsNews
# 974    WASHINGTON (Reuters) - Federal investigators p...  politicsNews
# ...                                                  ...           ...
# 21227  PARIS (Reuters) - French President Emmanuel Ma...     worldnews
# 21262  GUATEMALA CITY (Reuters) - Guatemala s top cou...     worldnews
# 21289  PARIS (Reuters) - Europe s  big four  continen...     worldnews
# 21352  BANGKOK (Reuters) - Ousted Thai prime minister...     worldnews
# 21407  GENEVA (Reuters) - North Korea and the United ...     worldnews
#
#                      date
# 445    November 30, 2017
# 778     November 8, 2017
# 892     November 2, 2017
# 896     November 2, 2017
# 974     October 30, 2017
# ...                   ...
# 21227    August 31, 2017
# 21262    August 29, 2017
# 21289    August 28, 2017
# 21352    August 25, 2017
# 21407    August 22, 2017
#
# [206 rows x 4 columns]

# %%
true_df = true_df.drop_duplicates()

# %%
true_df.shape
# Out:
# (21210, 4)

# %%
fake_df.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
true_df.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
df_true = true_df.copy()
df_fake = fake_df.copy()

# %%
df_true["class"]=1
df_fake["class"]=0

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obamas Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  class
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  class
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
df_fake["subject"].value_counts()
# Out:
# News               9050
# politics           6838
# left-news          4459
# Government News    1570
# US_News             783
# Middle-east         778
# Name: subject, dtype: int64

# %%
df_true["subject"].value_counts()
# Out:
# politicsNews    11219
# worldnews        9991
# Name: subject, dtype: int64

# %%
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'purple', 'orange']
explode1 = (0.1, 0, 0, 0, 0, 0)
explode2 = (0.1, 0)


# Create a subplot with two columns
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 6))

# Plot the first pie chart in the first subplot
fake_labels = df_fake["subject"].value_counts().index
fake_sizes = df_fake["subject"].value_counts().values
ax1.pie(fake_sizes, explode=explode1, labels=fake_labels, colors=colors, autopct='%1.1f%%')
ax1.axis('equal')
ax1.set_title('Distribution of Fake News Categories')

# Plot the second pie chart in the second subplot
true_labels = df_true["subject"].value_counts().index
true_sizes = df_true["subject"].value_counts().values
ax2.pie(true_sizes, labels=true_labels, autopct='%1.1f%%', explode=explode2)
ax2.axis('equal')
ax2.set_title('Distribution of True News Categories')

plt.tight_layout()
plt.show()

# %%
df_fake["date"][0]
# Out:
# 'December 31, 2017'

# %%
# Convert the 'date' column to datetime format
df_fake['date'] = pd.to_datetime(df_fake['date'], errors='coerce')
df_true['date'] = pd.to_datetime(df_true['date'], errors='coerce')

# %%
df_fake['date'][0]
# Out:
# Timestamp('2017-12-31 00:00:00')

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obamas Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject       date  class
# 0  Donald Trump just couldn t wish all Americans ...    News 2017-12-31      0
# 1  House Intelligence Committee Chairman Devin Nu...    News 2017-12-31      0
# 2  On Friday, it was revealed that former Milwauk...    News 2017-12-30      0
# 3  On Christmas day, Donald Trump announced that ...    News 2017-12-29      0
# 4  Pope Francis used his annual Christmas Day mes...    News 2017-12-25      0

# %%
# Extract year, month & day from the 'date' column
df_fake['year'] = df_fake['date'].dt.year
df_fake['month'] = df_fake['date'].dt.month_name()
df_fake['day'] = df_fake['date'].dt.day_name()
df_true['year'] = df_true['date'].dt.year
df_true['month'] = df_true['date'].dt.month_name()
df_true['day'] = df_true['date'].dt.day_name()

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obamas Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject       date  \
# 0  Donald Trump just couldn t wish all Americans ...    News 2017-12-31
# 1  House Intelligence Committee Chairman Devin Nu...    News 2017-12-31
# 2  On Friday, it was revealed that former Milwauk...    News 2017-12-30
# 3  On Christmas day, Donald Trump announced that ...    News 2017-12-29
# 4  Pope Francis used his annual Christmas Day mes...    News 2017-12-25
#
#    class    year     month       day
# 0      0  2017.0  December    Sunday
# 1      0  2017.0  December    Sunday
# 2      0  2017.0  December  Saturday
# 3      0  2017.0  December    Friday
# 4      0  2017.0  December    Monday

# %%
df_fake['year'].value_counts().plot(kind="bar")
plt.xlabel("Years")
plt.title("Yearwise Fake News Data")
# Out:
# Text(0.5, 1.0, 'Yearwise Fake News Data')

# %%
df_true['year'].value_counts()
# Out:
# 2017    16510
# 2016     4700
# Name: year, dtype: int64

# %%
df_true['year'].value_counts().plot(kind="bar")
plt.xlabel("Years")
plt.title("Yearwise True News Data")
# Out:
# Text(0.5, 1.0, 'Yearwise True News Data')

# %%
plt.figure(figsize=(6, 4))
df_fake['month'].value_counts().plot(kind="bar")
plt.xlabel("Months")
plt.title("Monthwise Fake News Data")
# Out:
# Text(0.5, 1.0, 'Monthwise Fake News Data')

# %%
plt.figure(figsize=(6, 4))
df_true['month'].value_counts().plot(kind="bar")
plt.xlabel("Months")
plt.title("Monthwise True News Data")
# Out:
# Text(0.5, 1.0, 'Monthwise True News Data')

# %%
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'purple', 'orange']
explode1 = (0.1, 0, 0, 0, 0, 0, 0)
explode2 = (0.1, 0, 0, 0, 0, 0, 0)


# Create a subplot with two columns
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8,4))

# Plot the first pie chart in the first subplot
fake_labels = df_fake["day"].value_counts().index
fake_sizes = df_fake["day"].value_counts().values
ax1.pie(fake_sizes, explode=explode1, labels=fake_labels, colors=colors, autopct='%1.1f%%')
ax1.axis('equal')
ax1.set_title('Daywise Fake News Data')

# Plot the second pie chart in the second subplot
true_labels = df_true["day"].value_counts().index
true_sizes = df_true["day"].value_counts().values
ax2.pie(true_sizes, labels=true_labels, autopct='%1.1f%%', explode=explode2)
ax2.axis('equal')
ax2.set_title('Daywise True News Data')

plt.tight_layout()
plt.show()

# %%
pd.crosstab(df_fake['subject'],df_fake['year'])
# Out:
# year             2015.0  2016.0  2017.0  2018.0
# subject
# Government News     581     597     390       0
# Middle-east           0     400     378       0
# News                  0    5841    3209       0
# US_News               0     405     378       0
# left-news           740    1805    1911       0
# politics           1157    2706    2935      35

# %%
fake_crosstab = pd.crosstab(df_fake['subject'], df_fake['year'])

# Create a heatmap using seaborn
plt.figure(figsize=(10, 6))
sns.heatmap(fake_crosstab, annot=True, cmap="YlGnBu",fmt = 'd')
plt.title('Fake News Subjects by Year (Heatmap)')
plt.xlabel('Year')
plt.ylabel('Subject')
plt.show()

# %%
pd.crosstab(df_true['subject'],df_true['year'])
# Out:
# year          2016  2017
# subject
# politicsNews  4700  6519
# worldnews        0  9991

# %%
true_crosstab = pd.crosstab(df_true['subject'], df_true['year'])

# Create a heatmap using seaborn
plt.figure(figsize=(10, 6))
sns.heatmap(true_crosstab, annot=True, cmap="YlGnBu",fmt='d')
plt.title('True News Subjects by Year (Heatmap)')
plt.xlabel('Year')
plt.ylabel('Subject')
plt.show()

# %%
df_fake = df_fake.drop(["year","month","day"], axis = 1)
df_true= df_true.drop(["year","month","day"], axis = 1)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### A: Text Cleaning

# %%
def word_drop(text):
    text = text.lower()
    text = re.sub('\[.*?\]','',text)
    text = re.sub("\\W"," ",text)
    text = re.sub('https?://\S+/www\.\S+','',text)
    text = re.sub("<.*?>+"," ",text)
    text = re.sub("[%s]" % re.escape(string.punctuation)," ",text)
    text = re.sub("\n"," ",text)
    text = re.sub("\w*\d\w*"," ",text)
    return text

# %%
df_fake["text"] = df_fake["text"].apply(word_drop)
df_fake["title"] = df_fake["title"].apply(word_drop)

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   donald trump sends out embarrassing new year ...
# 1   drunk bragging trump staffer started russian ...
# 2   sheriff david clarke becomes an internet joke...
# 3   trump is so obsessed he even has obama s name...
# 4   pope francis just called out donald trump dur...
#
#                                                 text subject       date  class
# 0  donald trump just couldn t wish all americans ...    News 2017-12-31      0
# 1  house intelligence committee chairman devin nu...    News 2017-12-31      0
# 2  on friday  it was revealed that former milwauk...    News 2017-12-30      0
# 3  on christmas day  donald trump announced that ...    News 2017-12-29      0
# 4  pope francis used his annual christmas day mes...    News 2017-12-25      0

# %%
df_true["text"] = df_true["text"].apply(word_drop)
df_true["title"] = df_true["title"].apply(word_drop)

# %%
df_true.head()
# Out:
#                                                title  \
# 0  as u s  budget fight looms  republicans flip t...
# 1  u s  military to accept transgender recruits o...
# 2  senior u s  republican senator   let mr  muell...
# 3  fbi russia probe helped by australian diplomat...
# 4  trump wants postal service to charge  much mor...
#
#                                                 text       subject       date  \
# 0  washington  reuters    the head of a conservat...  politicsNews 2017-12-31
# 1  washington  reuters    transgender people will...  politicsNews 2017-12-29
# 2  washington  reuters    the special counsel inv...  politicsNews 2017-12-31
# 3  washington  reuters    trump campaign adviser ...  politicsNews 2017-12-30
# 4  seattle washington  reuters    president donal...  politicsNews 2017-12-29
#
#    class
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ### B: Tokenization

# %%
# A function to tokenize the text
def tokenize_text(text):
    return word_tokenize(text)

# we can access the tokens for a specific row using df_true.at[index, "tokens"].

# %%
# Tokenize the preprocessed text and store it in a new column "tokens"
df_fake["text_tokens"] = df_fake["text"].apply(tokenize_text)


df_fake["title_tokens"] = df_fake["title"].apply(tokenize_text)

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   donald trump sends out embarrassing new year ...
# 1   drunk bragging trump staffer started russian ...
# 2   sheriff david clarke becomes an internet joke...
# 3   trump is so obsessed he even has obama s name...
# 4   pope francis just called out donald trump dur...
#
#                                                 text subject       date  \
# 0  donald trump just couldn t wish all americans ...    News 2017-12-31
# 1  house intelligence committee chairman devin nu...    News 2017-12-31
# 2  on friday  it was revealed that former milwauk...    News 2017-12-30
# 3  on christmas day  donald trump announced that ...    News 2017-12-29
# 4  pope francis used his annual christmas day mes...    News 2017-12-25
#
#    class                                        text_tokens  \
# 0      0  [donald, trump, just, couldn, t, wish, all, am...
# 1      0  [house, intelligence, committee, chairman, dev...
# 2      0  [on, friday, it, was, revealed, that, former, ...
# 3      0  [on, christmas, day, donald, trump, announced,...
# 4      0  [pope, francis, used, his, annual, christmas, ...
#
#                                         title_tokens
# 0  [donald, trump, sends, out, embarrassing, new,...
# 1  [drunk, bragging, trump, staffer, started, rus...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, is, so, obsessed, he, even, has, obama...
# 4  [pope, francis, just, called, out, donald, tru...

# %%
df_true["text_tokens"] = df_true["text"].apply(tokenize_text)
df_true["title_tokens"] = df_true["title"].apply(tokenize_text)

# %%
df_true.head()
# Out:
#                                                title  \
# 0  as u s  budget fight looms  republicans flip t...
# 1  u s  military to accept transgender recruits o...
# 2  senior u s  republican senator   let mr  muell...
# 3  fbi russia probe helped by australian diplomat...
# 4  trump wants postal service to charge  much mor...
#
#                                                 text       subject       date  \
# 0  washington  reuters    the head of a conservat...  politicsNews 2017-12-31
# 1  washington  reuters    transgender people will...  politicsNews 2017-12-29
# 2  washington  reuters    the special counsel inv...  politicsNews 2017-12-31
# 3  washington  reuters    trump campaign adviser ...  politicsNews 2017-12-30
# 4  seattle washington  reuters    president donal...  politicsNews 2017-12-29
#
#    class                                        text_tokens  \
# 0      1  [washington, reuters, the, head, of, a, conser...
# 1      1  [washington, reuters, transgender, people, wil...
# 2      1  [washington, reuters, the, special, counsel, i...
# 3      1  [washington, reuters, trump, campaign, adviser...
# 4      1  [seattle, washington, reuters, president, dona...
#
#                                         title_tokens
# 0  [as, u, s, budget, fight, looms, republicans, ...
# 1  [u, s, military, to, accept, transgender, recr...
# 2  [senior, u, s, republican, senator, let, mr, m...
# 3  [fbi, russia, probe, helped, by, australian, d...
# 4  [trump, wants, postal, service, to, charge, mu...

# %% [markdown]
# ### C: Removal Of Stopwords

# %%
def remove_stopwords(tokens):
    stop_words = set(stopwords.words('english'))
    meaningful_tokens = [token for token in tokens if token.lower() not in stop_words]
    return meaningful_tokens

# %%
df_fake["text_tokens"] = df_fake["text_tokens"].apply(remove_stopwords)
df_fake["title_tokens"] = df_fake["title_tokens"].apply(remove_stopwords)

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   donald trump sends out embarrassing new year ...
# 1   drunk bragging trump staffer started russian ...
# 2   sheriff david clarke becomes an internet joke...
# 3   trump is so obsessed he even has obama s name...
# 4   pope francis just called out donald trump dur...
#
#                                                 text subject       date  \
# 0  donald trump just couldn t wish all americans ...    News 2017-12-31
# 1  house intelligence committee chairman devin nu...    News 2017-12-31
# 2  on friday  it was revealed that former milwauk...    News 2017-12-30
# 3  on christmas day  donald trump announced that ...    News 2017-12-29
# 4  pope francis used his annual christmas day mes...    News 2017-12-25
#
#    class                                        text_tokens  \
# 0      0  [donald, trump, wish, americans, happy, new, y...
# 1      0  [house, intelligence, committee, chairman, dev...
# 2      0  [friday, revealed, former, milwaukee, sheriff,...
# 3      0  [christmas, day, donald, trump, announced, wou...
# 4      0  [pope, francis, used, annual, christmas, day, ...
#
#                                         title_tokens
# 0  [donald, trump, sends, embarrassing, new, year...
# 1  [drunk, bragging, trump, staffer, started, rus...
# 2  [sheriff, david, clarke, becomes, internet, jo...
# 3  [trump, obsessed, even, obama, name, coded, we...
# 4  [pope, francis, called, donald, trump, christm...

# %%
df_true["text_tokens"] = df_true["text_tokens"].apply(remove_stopwords)
df_true["title_tokens"] = df_true["title_tokens"].apply(remove_stopwords)

# %%
df_true.head()
# Out:
#                                                title  \
# 0  as u s  budget fight looms  republicans flip t...
# 1  u s  military to accept transgender recruits o...
# 2  senior u s  republican senator   let mr  muell...
# 3  fbi russia probe helped by australian diplomat...
# 4  trump wants postal service to charge  much mor...
#
#                                                 text       subject       date  \
# 0  washington  reuters    the head of a conservat...  politicsNews 2017-12-31
# 1  washington  reuters    transgender people will...  politicsNews 2017-12-29
# 2  washington  reuters    the special counsel inv...  politicsNews 2017-12-31
# 3  washington  reuters    trump campaign adviser ...  politicsNews 2017-12-30
# 4  seattle washington  reuters    president donal...  politicsNews 2017-12-29
#
#    class                                        text_tokens  \
# 0      1  [washington, reuters, head, conservative, repu...
# 1      1  [washington, reuters, transgender, people, all...
# 2      1  [washington, reuters, special, counsel, invest...
# 3      1  [washington, reuters, trump, campaign, adviser...
# 4      1  [seattle, washington, reuters, president, dona...
#
#                                         title_tokens
# 0  [u, budget, fight, looms, republicans, flip, f...
# 1  [u, military, accept, transgender, recruits, m...
# 2  [senior, u, republican, senator, let, mr, muel...
# 3  [fbi, russia, probe, helped, australian, diplo...
# 4  [trump, wants, postal, service, charge, much, ...

# %%
df_true['title_tokens'][0]
# Out:
# ['u', 'budget', 'fight', 'looms', 'republicans', 'flip', 'fiscal', 'script']

# %% [markdown]
# ### D: Lemmatization

# %%
# Initialize WordNet Lemmatizer
lemmatizer = WordNetLemmatizer()

# Function to lemmatize a list of tokens
def lemmatize_tokens(tokens):
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return lemmatized_tokens

# %%
# Applying lemmatization to the 'text' & 'title' tokens column
df_fake['text_tokens'] = df_fake['text_tokens'].apply(lemmatize_tokens)
df_fake['title_tokens'] = df_fake['title_tokens'].apply(lemmatize_tokens)

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   donald trump sends out embarrassing new year ...
# 1   drunk bragging trump staffer started russian ...
# 2   sheriff david clarke becomes an internet joke...
# 3   trump is so obsessed he even has obama s name...
# 4   pope francis just called out donald trump dur...
#
#                                                 text subject       date  \
# 0  donald trump just couldn t wish all americans ...    News 2017-12-31
# 1  house intelligence committee chairman devin nu...    News 2017-12-31
# 2  on friday  it was revealed that former milwauk...    News 2017-12-30
# 3  on christmas day  donald trump announced that ...    News 2017-12-29
# 4  pope francis used his annual christmas day mes...    News 2017-12-25
#
#    class                                        text_tokens  \
# 0      0  [donald, trump, wish, american, happy, new, ye...
# 1      0  [house, intelligence, committee, chairman, dev...
# 2      0  [friday, revealed, former, milwaukee, sheriff,...
# 3      0  [christmas, day, donald, trump, announced, wou...
# 4      0  [pope, francis, used, annual, christmas, day, ...
#
#                                         title_tokens
# 0  [donald, trump, sends, embarrassing, new, year...
# 1  [drunk, bragging, trump, staffer, started, rus...
# 2  [sheriff, david, clarke, becomes, internet, jo...
# 3  [trump, obsessed, even, obama, name, coded, we...
# 4  [pope, francis, called, donald, trump, christm...

# %%
df_true['text_tokens'] = df_true['text_tokens'].apply(lemmatize_tokens)
df_true['title_tokens'] = df_true['title_tokens'].apply(lemmatize_tokens)

# %%
df_true.head()
# Out:
#                                                title  \
# 0  as u s  budget fight looms  republicans flip t...
# 1  u s  military to accept transgender recruits o...
# 2  senior u s  republican senator   let mr  muell...
# 3  fbi russia probe helped by australian diplomat...
# 4  trump wants postal service to charge  much mor...
#
#                                                 text       subject       date  \
# 0  washington  reuters    the head of a conservat...  politicsNews 2017-12-31
# 1  washington  reuters    transgender people will...  politicsNews 2017-12-29
# 2  washington  reuters    the special counsel inv...  politicsNews 2017-12-31
# 3  washington  reuters    trump campaign adviser ...  politicsNews 2017-12-30
# 4  seattle washington  reuters    president donal...  politicsNews 2017-12-29
#
#    class                                        text_tokens  \
# 0      1  [washington, reuters, head, conservative, repu...
# 1      1  [washington, reuters, transgender, people, all...
# 2      1  [washington, reuters, special, counsel, invest...
# 3      1  [washington, reuters, trump, campaign, adviser...
# 4      1  [seattle, washington, reuters, president, dona...
#
#                                         title_tokens
# 0  [u, budget, fight, loom, republican, flip, fis...
# 1  [u, military, accept, transgender, recruit, mo...
# 2  [senior, u, republican, senator, let, mr, muel...
# 3  [fbi, russia, probe, helped, australian, diplo...
# 4  [trump, want, postal, service, charge, much, a...

# %% [markdown]
# ### Representation of Wordcloud

# %%
# Combine all the lemmatized tokens into a single list
all_fake_lemmatized_text = [token for tokens_list in df_fake["text_tokens"] for token in tokens_list]
all_fake_lemmatized_title = [token for tokens_list in df_fake["title_tokens"] for token in tokens_list]

# %%
# Count the frequency of each lemmatized word
fake_text_freq = Counter(all_fake_lemmatized_text)
fake_title_freq = Counter(all_fake_lemmatized_title)

# %%
fake_text_freq
# Out:
# Counter({'donald': 17662,
#          'trump': 79369,
#          'wish': 778,
#          'american': 18106,
#          'happy': 998,
#          'new': 14366,
#          'year': 19047,
#          'leave': 1649,
#          'instead': 3188,
#          'give': 3898,
#          'shout': 156,
#          'enemy': 1019,
#          'hater': 226,
#          'dishonest': 287,
#          'fake': 3006,
#          'news': 14610,
#          'medium': 11792,
#          'former': 7289,
#          'reality': 2008,
#          'show': 8327,
#          'star': 1794,
#          'one': 25382,
#          'job': 5297,
#          'country': 11443,
#          'rapidly': 175,
#          'grows': 61,
#          'stronger': 255,
#          'smarter': 71,
#          'want': 9885,
#          'friend': 3266,
#          'supporter': 5030,
#          'even': 14009,
#          'healthy': 247,
#          'president': 28269,
#          'angry': 1040,
#          'pant': 225,
#          'tweeted': 1632,
#          'great': 4304,
#          'america': 11244,
#          'j': 3861,
#          'realdonaldtrump': 4370,
#          'december': 2462,
#          'tweet': 3456,
#          'went': 4491,
#          'welll': 1,
#          'expect': 1039,
#          'kind': 2561,
#          'sends': 156,
#          'greeting': 37,
#          'like': 18637,
#          'despicable': 169,
#          'petty': 197,
#          'infantile': 8,
#          'gibberish': 12,
#          'lack': 1090,
#          'decency': 147,
#          'allow': 1495,
#          'rise': 925,
#          'gutter': 44,
#          'long': 4636,
#          'enough': 3286,
#          'citizen': 3165,
#          'bishop': 174,
#          'talbert': 2,
#          'swan': 18,
#          'talbertswan': 2,
#          'calvin': 15,
#          'calvinstowell': 6,
#          'impeachment': 428,
#          'would': 23550,
#          'make': 11631,
#          'also': 15401,
#          'accept': 801,
#          'regaining': 8,
#          'control': 2871,
#          'congress': 3736,
#          'miranda': 38,
#          'yaver': 2,
#          'mirandayaver': 2,
#          'hear': 1459,
#          'talk': 3058,
#          'include': 1253,
#          'many': 9944,
#          'people': 26621,
#          'hate': 3289,
#          'wonder': 1038,
#          'alan': 151,
#          'sandoval': 12,
#          'us': 531,
#          'word': 4293,
#          'marlene': 4,
#          'say': 15776,
#          'koren': 1,
#          'pollitt': 1,
#          'korencarpenter': 1,
#          'eve': 232,
#          'including': 4500,
#          'fought': 489,
#          'lost': 2102,
#          'badly': 342,
#          'know': 12055,
#          'love': 2760,
#          'nothing': 4273,
#          'directed': 513,
#          'message': 2741,
#          'easter': 117,
#          'thanksgiving': 114,
#          'anniversary': 192,
#          'pic': 6322,
#          'twitter': 11722,
#          'com': 8336,
#          'daniel': 395,
#          'dale': 39,
#          'holiday': 425,
#          'clearly': 2366,
#          'presidential': 5736,
#          'work': 6105,
#          'hallmark': 42,
#          'becoming': 1118,
#          'steven': 273,
#          'goodine': 1,
#          'sgoodine': 1,
#          'always': 2267,
#          'difference': 883,
#          'last': 8258,
#          'filter': 60,
#          'breaking': 780,
#          'roy': 524,
#          'schulze': 2,
#          'thbthttt': 1,
#          'apart': 452,
#          'teenager': 227,
#          'term': 2547,
#          'wendy': 65,
#          'wendywhistles': 1,
#          'fucking': 204,
#          'old': 4782,
#          'voted': 1514,
#          'hole': 385,
#          'thinking': 948,
#          'change': 4296,
#          'got': 4983,
#          'power': 3806,
#          'wrong': 2267,
#          'men': 3360,
#          'older': 260,
#          'photo': 2661,
#          'andrew': 882,
#          'burton': 88,
#          'getty': 4141,
#          'image': 14315,
#          'house': 11280,
#          'intelligence': 3679,
#          'committee': 3114,
#          'chairman': 1172,
#          'devin': 142,
#          'nunes': 367,
#          'going': 9805,
#          'bad': 2760,
#          'day': 10150,
#          'assumption': 121,
#          'u': 24484,
#          'christopher': 385,
#          'steele': 293,
#          'dossier': 621,
#          'prompted': 295,
#          'russia': 5965,
#          'investigation': 4752,
#          'lashing': 75,
#          'department': 5765,
#          'justice': 4191,
#          'fbi': 5789,
#          'order': 4598,
#          'protect': 1673,
#          'happens': 933,
#          'started': 1789,
#          'according': 8073,
#          'document': 2760,
#          'obtained': 734,
#          'york': 4405,
#          'time': 19199,
#          'campaign': 11585,
#          'adviser': 1059,
#          'george': 2065,
#          'papadopoulos': 100,
#          'drunk': 174,
#          'wine': 58,
#          'bar': 702,
#          'revealed': 1428,
#          'knowledge': 647,
#          'russian': 5509,
#          'opposition': 1006,
#          'research': 1221,
#          'hillary': 14085,
#          'clinton': 19778,
#          'top': 2997,
#          'covfefe': 40,
#          'boy': 1360,
#          'administration': 5860,
#          'alleged': 1655,
#          'much': 7135,
#          'larger': 451,
#          'role': 1909,
#          'none': 1075,
#          'damning': 216,
#          'drunken': 64,
#          'fool': 280,
#          'coffee': 216,
#          'help': 4613,
#          'arrange': 51,
#          'meeting': 3107,
#          'abdel': 47,
#          'fattah': 9,
#          'el': 363,
#          'sisi': 21,
#          'egypt': 173,
#          'two': 9111,
#          'month': 5037,
#          'election': 10295,
#          'known': 2941,
#          'aide': 990,
#          'set': 2572,
#          'world': 7463,
#          'leader': 4358,
#          'team': 2956,
#          'ran': 889,
#          'merely': 366,
#          'may': 7695,
#          'australian': 151,
#          'diplomat': 325,
#          'alexander': 176,
#          'downer': 2,
#          'official': 6638,
#          'shopping': 160,
#          'around': 4743,
#          'possible': 2129,
#          'dirt': 185,
#          'democratic': 4892,
#          'nominee': 2787,
#          'exactly': 1848,
#          'mr': 4688,
#          'said': 33760,
#          'night': 3792,
#          'kensington': 6,
#          'room': 2659,
#          'unclear': 387,
#          'report': 7880,
#          'state': 23625,
#          'later': 2973,
#          'leaked': 588,
#          'email': 5020,
#          'began': 2203,
#          'appearing': 303,
#          'online': 1091,
#          'passed': 1118,
#          'information': 4263,
#          'counterpart': 151,
#          'four': 2658,
#          'current': 1949,
#          'foreign': 3424,
#          'direct': 942,
#          'pleaded': 179,
#          'guilty': 816,
#          'lying': 1253,
#          'f': 1635,
#          'b': 1423,
#          'cooperating': 89,
#          'witness': 891,
#          'special': 2486,
#          'counsel': 860,
#          'robert': 1479,
#          'mueller': 911,
#          'presidency': 1859,
#          'scripted': 89,
#          'tv': 2203,
#          'win': 3400,
#          'mcnamee': 278,
#          'friday': 2486,
#          'milwaukee': 192,
#          'sheriff': 1010,
#          'david': 1632,
#          'clarke': 138,
#          'considered': 953,
#          'homeland': 771,
#          'security': 5868,
#          'secretary': 3788,
#          'scandal': 1632,
#          'january': 3547,
#          'brief': 449,
#          'run': 2962,
#          'plane': 643,
#          'fellow': 1046,
#          'passenger': 431,
#          'dan': 436,
#          'black': 8336,
#          'detained': 249,
#          'police': 9112,
#          'reason': 3717,
#          'whatsoever': 235,
#          'except': 606,
#          'maybe': 1663,
#          'feeling': 824,
#          'hurt': 937,
#          'messaged': 15,
#          'stop': 3789,
#          'deplaned': 1,
#          'search': 709,
#          'warrant': 390,
#          'executed': 189,
#          'see': 7908,
#          'exchange': 1043,
#          'calling': 2504,
#          'though': 4060,
#          'copy': 403,
#          'internet': 1257,
#          'unintimidated': 2,
#          'lib': 24,
#          'attempt': 2053,
#          'smear': 263,
#          'discredit': 244,
#          'designed': 788,
#          'silence': 494,
#          'continue': 2627,
#          'poke': 35,
#          'eye': 1208,
#          'sharp': 229,
#          'stick': 344,
#          'bitch': 204,
#          'slap': 150,
#          'scum': 63,
#          'bag': 293,
#          'til': 27,
#          'get': 12362,
#          'attacked': 1150,
#          'better': 3261,
#          'maga': 271,
#          'jr': 1189,
#          'sheriffclarke': 18,
#          'antidote': 8,
#          'go': 8716,
#          'right': 14848,
#          'punch': 198,
#          'nose': 156,
#          'taste': 156,
#          'blood': 760,
#          'bully': 493,
#          'attention': 1410,
#          'neverbackdown': 1,
#          'called': 6424,
#          'local': 2390,
#          'newspaper': 679,
#          'chose': 624,
#          'file': 1168,
#          'charge': 2444,
#          'mean': 4331,
#          'especially': 2033,
#          'lie': 2862,
#          'decision': 3332,
#          'filed': 982,
#          'http': 4318,
#          'co': 4443,
#          'keithleblanc': 1,
#          'hope': 2199,
#          'rest': 1412,
#          'village': 217,
#          'implicated': 82,
#          'kirk': 98,
#          'ketchum': 3,
#          'kirkketchum': 1,
#          'baked': 75,
#          'potato': 42,
#          'french': 406,
#          'fry': 105,
#          'fwfxszupxy': 1,
#          'alt': 563,
#          'immigration': 3170,
#          'uscis': 34,
#          'ymsobljfxu': 1,
#          'pendulum': 24,
#          'swinger': 1,
#          'pendulumswngr': 1,
#          'stand': 3151,
#          'someone': 3406,
#          'made': 9116,
#          'fun': 663,
#          'hat': 472,
#          'chris': 1221,
#          'jackson': 760,
#          'chriscjackson': 5,
#          'masterful': 17,
#          'pshop': 1,
#          'seem': 1368,
#          'never': 6325,
#          'tire': 65,
#          'think': 9914,
#          'steely': 4,
#          'resolve': 162,
#          'visible': 137,
#          'mohney': 1,
#          'chrismohney': 1,
#          'indicating': 128,
#          'finger': 411,
#          'died': 1102,
#          'jail': 852,
#          'short': 1509,
#          'dipshit': 10,
#          'ike': 27,
#          'barinholtz': 1,
#          'ikebarinholtz': 1,
#          'tough': 647,
#          'guy': 3003,
#          'flair': 10,
#          'ulcfddhkdy': 1,
#          'kellmecrazy': 1,
#          'kel': 10,
#          'moonface': 1,
#          'edgy': 23,
#          'buddy': 179,
#          'smh': 26,
#          'break': 1115,
#          'applebees': 1,
#          'aaron': 181,
#          'trying': 3649,
#          'earn': 186,
#          'still': 5872,
#          'relevant': 304,
#          'badge': 104,
#          'circusrebel': 1,
#          'circusdrew': 1,
#          'sure': 3167,
#          'hydrate': 3,
#          'drink': 258,
#          'lot': 3538,
#          'water': 2581,
#          'rumored': 54,
#          'prisoner': 366,
#          'denied': 823,
#          'prison': 1311,
#          'klinc': 1,
#          'thomas': 563,
#          'man': 6620,
#          'thirst': 19,
#          'county': 2403,
#          'cell': 403,
#          'april': 2214,
#          'victim': 2699,
#          'homicide': 199,
#          'thought': 2844,
#          'point': 5520,
#          'repeated': 417,
#          'spencer': 364,
#          'platt': 166,
#          'christmas': 596,
#          'announced': 1915,
#          'back': 9033,
#          'following': 2781,
#          'golfing': 114,
#          'fourth': 351,
#          'row': 192,
#          'blasted': 349,
#          'barack': 2747,
#          'obama': 18751,
#          'playing': 904,
#          'golf': 682,
#          'track': 665,
#          'outpace': 4,
#          'number': 4583,
#          'game': 1478,
#          'predecessor': 230,
#          'played': 843,
#          'updated': 134,
#          'tracker': 15,
#          'appearance': 898,
#          'property': 940,
#          'round': 530,
#          'today': 4910,
#          'pace': 138,
#          'pas': 1072,
#          'first': 10610,
#          'total': 1397,
#          'july': 2972,
#          'next': 3413,
#          'philip': 89,
#          'bump': 74,
#          'pbump': 5,
#          'washington': 5733,
#          'post': 5420,
#          'reporter': 3076,
#          'discovered': 569,
#          'website': 1756,
#          'really': 6213,
#          'weird': 260,
#          'everything': 2377,
#          'bizarre': 467,
#          'af': 17,
#          'coding': 10,
#          'contained': 306,
#          'reference': 793,
#          'unlike': 504,
#          'working': 3183,
#          'fix': 528,
#          'problem': 3752,
#          'course': 3900,
#          'however': 4331,
#          'done': 3266,
#          'correctly': 172,
#          'spent': 1566,
#          'several': 3172,
#          'coded': 32,
#          'serve': 994,
#          'event': 4120,
#          'internal': 493,
#          'server': 1080,
#          'error': 322,
#          'zrwpymxrcz': 1,
#          'ingraham': 83,
#          'cingraham': 6,
#          'snippet': 43,
#          'code': 606,
#          'appears': 1700,
#          'page': 2340,
#          'footer': 3,
#          'paid': 1878,
#          'rnc': 488,
#          'others': 2682,
#          'noted': 1028,
#          'thread': 104,
#          'clear': 3413,
#          'ever': 4373,
#          'actually': 4951,
#          'display': 567,
#          'deleted': 377,
#          'update': 463,
#          'removed': 943,
#          'gop': 4422,
#          'fixed': 132,
#          'javascript': 1,
#          'v': 1169,
#          'since': 6358,
#          'actual': 1013,
#          'presumably': 208,
#          'different': 2226,
#          'suggests': 393,
#          'either': 2031,
#          'admin': 51,
#          'sensitive': 432,
#          'issue': 4834,
#          'away': 3645,
#          'quickly': 1146,
#          'noticed': 341,
#          'idea': 2828,
#          'led': 1782,
#          'cked': 42,
#          'best': 2989,
#          'part': 5660,
#          'using': 2739,
#          'assignment': 138,
#          'operator': 167,
#          'bit': 1141,
#          'look': 5451,
#          'line': 2884,
#          'errorcode': 1,
#          'coder': 1,
#          'nobody': 843,
#          'surprised': 481,
#          'tim': 445,
#          'peterson': 91,
#          'timrpeterson': 1,
#          'obsessed': 230,
#          'name': 3348,
#          'joe': 1673,
#          'raedle': 200,
#          'pope': 497,
#          'francis': 269,
#          'used': 4590,
#          'annual': 521,
#          'rebuke': 102,
#          'without': 3891,
#          'mentioning': 130,
#          'delivered': 555,
#          'member': 6443,
#          'united': 8003,
#          'nation': 5708,
#          'condemned': 307,
#          'move': 2436,
#          'recognize': 462,
#          'jerusalem': 364,
#          'capital': 668,
#          'israel': 1597,
#          'pontiff': 24,
#          'prayed': 48,
#          'monday': 2338,
#          'peaceful': 433,
#          'coexistence': 5,
#          'within': 2119,
#          'mutually': 31,
#          'agreed': 758,
#          'internationally': 132,
#          'recognized': 249,
#          'border': 3033,
#          'jesus': 513,
#          'child': 5974,
#          'middle': 2063,
#          'east': 1322,
#          'suffer': 286,
#          'growing': 813,
#          'tension': 409,
#          'israeli': 725,
#          'palestinian': 497,
#          'festive': 4,
#          'let': 4647,
#          'ask': 1632,
#          'lord': 349,
#          'peace': 934,
#          'holy': 230,
#          'land': 1146,
#          'pray': 313,
#          'resume': 130,
#          'dialogue': 185,
#          'prevail': 49,
#          'party': 8543,
#          'negotiated': 103,
#          'solution': 628,
#          'finally': 1602,
#          'reached': 690,
#          'plead': 63,
#          'acceptance': 172,
#          'refugee': 3297,
#          'forced': 1364,
#          'home': 3959,
#          'continues': 1329,
#          'fight': 2351,
#          'place': 4514,
#          'inn': 55,
#          'analogy': 75,
#          'wind': 231,
#          'war': 5412,
#          'blowing': 129,
#          'outdated': 49,
#          'model': 613,
#          'development': 772,
#          'produce': 363,
#          'human': 2449,
#          'societal': 31,
#          'environmental': 498,
#          'decline': 274,
#          'invite': 187,
#          'focus': 1002,
#          'sign': 1855,
#          'face': 3102,
#          'little': 3648,
#          'well': 8615,
#          'pain': 383,
#          'welcomed': 144,
#          'hard': 2779,
#          'lay': 285,
#          'head': 2770,
#          'added': 2197,
#          'heart': 1233,
#          'closed': 544,
#          'bethlehem': 20,
#          'mary': 189,
#          'joseph': 405,
#          'immigrant': 2825,
#          'struggled': 98,
#          'find': 2942,
#          'safe': 1393,
#          'stay': 1250,
#          'comfortable': 220,
#          'easy': 753,
#          'journey': 140,
#          'young': 2717,
#          'couple': 1216,
#          'full': 2872,
#          'expectation': 146,
#          'born': 1163,
#          'yet': 3819,
#          'step': 1546,
#          'weighed': 135,
#          'uncertainty': 103,
#          'danger': 725,
#          'attend': 550,
#          'behind': 2598,
#          'footstep': 49,
#          'hidden': 294,
#          'sunday': 2223,
#          'entire': 2669,
#          'family': 6363,
#          'million': 7202,
#          'person': 4079,
#          'choose': 683,
#          'driven': 344,
#          'dear': 289,
#          'amen': 46,
#          'furlong': 19,
#          'case': 6128,
#          'cop': 1597,
#          'brutalizing': 6,
#          'killing': 1166,
#          'color': 954,
#          'seems': 2578,
#          'end': 3944,
#          'another': 6485,
#          'need': 7225,
#          'shared': 791,
#          'far': 4058,
#          'wide': 486,
#          'alabama': 790,
#          'woman': 11545,
#          'angela': 245,
#          'williams': 648,
#          'graphic': 170,
#          'son': 2165,
#          'hospital': 935,
#          'bed': 430,
#          'beaten': 235,
#          'fractured': 54,
#          'facebook': 3360,
#          'unacceptable': 201,
#          'custody': 429,
#          'sort': 1184,
#          'altercation': 69,
#          'resulted': 300,
#          'arrest': 973,
#          'realize': 607,
#          'detail': 1479,
#          'matter': 5015,
#          'supposed': 1186,
#          'beat': 708,
#          'brutalize': 14,
#          'm': 695,
#          'express': 526,
#          'body': 1394,
#          'camera': 859,
#          'beating': 369,
#          'convenient': 91,
#          'malfunction': 15,
#          'explain': 987,
#          'existence': 335,
#          'dash': 113,
#          'footage': 686,
#          'brutal': 427,
#          'hell': 1103,
#          'could': 10244,
#          'described': 1281,
#          'attempted': 790,
#          'murder': 1421,
#          'something': 5001,
#          'tell': 3856,
#          'ado': 19,
#          'troy': 42,
#          'finest': 71,
#          'decided': 2264,
#          'appropriate': 554,
#          'treatment': 737,
#          'perceived': 193,
#          'crime': 3286,
#          'might': 3608,
#          'completely': 1696,
#          'rot': 25,
#          'wan': 100,
#          'na': 989,
#          'bet': 331,
#          'vacation': 473,
#          'force': 3240,
#          'investigates': 54,
#          'officer': 4738,
#          'returned': 453,
#          'duty': 714,
#          'posthaste': 5,
#          'folk': 731,
#          'life': 7457,
#          'way': 9765,
#          'happened': 2668,
#          'white': 13540,
#          'please': 1369,
#          'share': 1435,
#          'tuned': 111,
#          'addicting': 85,
#          'info': 280,
#          'featured': 8260,
#          'via': 12774,
#          'mcnew': 10,
#          'stringer': 24,
#          'good': 5707,
#          'portion': 344,
#          'club': 895,
#          'marking': 72,
#          'taking': 2854,
#          'oath': 394,
#          'office': 6015,
#          'must': 3122,
#          'lashed': 135,
#          'deputy': 946,
#          'director': 3338,
#          'mccabe': 514,
#          'saying': 5161,
#          'plan': 3717,
#          'retire': 79,
#          'follows': 307,
#          'testimony': 714,
#          'front': 2213,
#          'congressional': 1370,
#          'week': 6678,
#          'mounting': 101,
#          'criticism': 795,
#          'republican': 16713,
#          'regarding': 1387,
#          'probe': 581,
#          'naturally': 314,
#          'along': 2566,
#          'leakin': 6,
#          'james': 1942,
#          'comey': 2477,
#          'phony': 320,
#          'illegally': 720,
#          'given': 2835,
#          'wife': 2105,
#          'puppet': 244,
#          'racing': 33,
#          'clock': 253,
#          'benefit': 1338,
#          'lawyer': 1687,
#          'baker': 245,
#          'reassigned': 21,
#          'foxnews': 366,
#          'intel': 309,
#          'disposal': 44,
#          'getting': 2844,
#          'fox': 5394,
#          'career': 1036,
#          'terrorism': 1542,
#          'fact': 7702,
#          'checked': 205,
#          'claim': 4891,
#          'receiving': 541,
#          'politifact': 101,
#          'late': 1454,
#          'significant': 807,
#          'distortion': 27,
#          'implication': 245,
#          'political': 7650,
#          'favor': 1101,
#          'sense': 1307,
#          'evidence': 3113,
#          'rated': 152,
#          'mostly': 754,
#          'false': 1550,
#          'repeat': 211,
#          'believe': 4327,
#          'bothering': 27,
#          'google': 640,
#          'zach': 75,
#          'gibson': 146,
#          'pool': 599,
#          'wake': 666,
#          'court': 5790,
#          'derailed': 44,
#          'muslim': 6245,
#          'entering': 552,
#          'published': 1285,
#          'saturday': 1678,
#          'morning': 2561,
#          'detailing': 95,
#          'frustration': 207,
#          'article': 2247,
#          'june': 2657,
#          'stomped': 16,
#          'oval': 476,
#          'furious': 312,
#          'travel': 987,
#          'ban': 1687,
#          'implemented': 176,
#          'fully': 625,
#          'fumed': 9,
#          'visa': 865,
#          'already': 3792,
#          'issued': 1149,
#          'rate': 1256,
#          'looked': 718,
#          'making': 3514,
#          'broad': 244,
#          'pronouncement': 25,
#          'reading': 589,
#          'advisor': 517,
#          'supremacist': 1005,
#          'stephen': 743,
#          'miller': 689,
#          'handed': 467,
#          'cabinet': 544,
#          'listed': 453,
#          'included': 1210,
#          'afghanistan': 751,
#          'haiti': 290,
#          'nigeria': 19,
#          'sensing': 23,
#          'pattern': 382,
#          'expressed': 603,
#          'dismay': 43,
#          'spoke': 1471,
#          'condition': 920,
#          'anonymity': 189,
#          'interviewed': 499,
#          'three': 4051,
#          'dozen': 896,
#          'fault': 311,
#          'read': 4719,
#          'terrorist': 3810,
#          'hut': 19,
#          'saw': 1579,
#          'glory': 84,
#          'aid': 686,
#          'despite': 2502,
#          'extensive': 236,
#          'denies': 193,
#          'language': 1014,
#          'racist': 3684,
#          'history': 3671,
#          'blatant': 219,
#          'nationalism': 105,
#          'surprise': 837,
#          'freedom': 1852,
#          'act': 4038,
#          'request': 1388,
#          'turned': 1773,
#          'question': 5223,
#          'statement': 5072,
#          'printed': 116,
#          'inline': 4,
#          'commentary': 216,
#          'punctuate': 4,
#          'anger': 522,
#          'responsible': 1186,
#          'carnage': 81,
#          'speech': 4399,
#          'inauguration': 918,
#          'menace': 35,
#          'represent': 593,
#          'anything': 3535,
#          'indictment': 344,
#          'speak': 1690,
#          'kleponis': 11,
#          'raised': 965,
#          'alarm': 252,
#          'dangerously': 77,
#          'close': 1936,
#          'autocrat': 33,
#          'thing': 9183,
#          'democracy': 1034,
#          'become': 3360,
#          'autocracy': 15,
#          'often': 1707,
#          'beginning': 940,
#          'phase': 142,
#          'explained': 1130,
#          'frum': 29,
#          'piece': 1327,
#          'atlantic': 257,
#          'build': 1031,
#          'critically': 73,
#          'happening': 967,
#          'systematic': 69,
#          'discrediting': 24,
#          'vital': 183,
#          'institution': 780,
#          'free': 3642,
#          'press': 4642,
#          'federal': 5404,
#          'bureau': 647,
#          'weaponization': 9,
#          'opponent': 815,
#          'chamber': 299,
#          'representative': 1174,
#          'rogue': 190,
#          'band': 347,
#          'running': 2389,
#          'parallel': 108,
#          'collusion': 619,
#          'explicit': 104,
#          'intent': 470,
#          'undermining': 110,
#          'possibly': 852,
#          'swing': 368,
#          'starter': 76,
#          'ambassador': 798,
#          'nikki': 88,
#          'haley': 159,
#          'threaten': 360,
#          'policy': 5458,
#          'come': 7819,
#          'recognition': 132,
#          'jewish': 597,
#          'expert': 1140,
#          'usually': 532,
#          'quite': 1326,
#          'measured': 84,
#          'autocratic': 26,
#          'antic': 139,
#          'cia': 2118,
#          'john': 4009,
#          ...})

# %%
fake_title_freq
# Out:
# Counter({'donald': 848,
#          'trump': 9349,
#          'sends': 60,
#          'embarrassing': 80,
#          'new': 905,
#          'year': 464,
#          'eve': 13,
#          'message': 193,
#          'disturbing': 61,
#          'drunk': 28,
#          'bragging': 23,
#          'staffer': 64,
#          'started': 31,
#          'russian': 348,
#          'collusion': 53,
#          'investigation': 175,
#          'sheriff': 96,
#          'david': 52,
#          'clarke': 26,
#          'becomes': 28,
#          'internet': 125,
#          'joke': 72,
#          'threatening': 52,
#          'poke': 4,
#          'people': 515,
#          'eye': 48,
#          'obsessed': 33,
#          'even': 191,
#          'obama': 2581,
#          'name': 114,
#          'coded': 1,
#          'website': 54,
#          'image': 386,
#          'pope': 52,
#          'francis': 17,
#          'called': 153,
#          'christmas': 79,
#          'speech': 443,
#          'racist': 524,
#          'alabama': 51,
#          'cop': 479,
#          'brutalize': 2,
#          'black': 973,
#          'boy': 132,
#          'handcuff': 7,
#          'graphic': 8,
#          'fresh': 1,
#          'golf': 53,
#          'course': 29,
#          'lash': 23,
#          'fbi': 434,
#          'deputy': 34,
#          'director': 175,
#          'james': 100,
#          'comey': 216,
#          'said': 194,
#          'insanely': 10,
#          'stuff': 18,
#          'inside': 58,
#          'oval': 23,
#          'office': 141,
#          'witness': 24,
#          'back': 437,
#          'former': 317,
#          'cia': 131,
#          'slam': 160,
#          'un': 103,
#          'bullying': 9,
#          'openly': 42,
#          'suggests': 49,
#          'acting': 24,
#          'like': 409,
#          'dictator': 40,
#          'tweet': 935,
#          'watch': 1932,
#          'brand': 21,
#          'pro': 220,
#          'ad': 186,
#          'feature': 10,
#          'much': 129,
#          'kissing': 8,
#          'make': 776,
#          'sick': 93,
#          'papa': 3,
#          'john': 238,
#          'founder': 45,
#          'retires': 1,
#          'figure': 22,
#          'racism': 112,
#          'bad': 141,
#          'business': 119,
#          'paul': 217,
#          'ryan': 177,
#          'told': 159,
#          'u': 1148,
#          'care': 121,
#          'struggling': 3,
#          'family': 229,
#          'living': 54,
#          'blue': 26,
#          'state': 593,
#          'news': 883,
#          'mitch': 36,
#          'mcconnell': 57,
#          'say': 756,
#          'repealing': 5,
#          'obamacare': 182,
#          'lindsey': 33,
#          'graham': 32,
#          'trash': 73,
#          'medium': 702,
#          'portraying': 1,
#          'kooky': 1,
#          'forgets': 17,
#          'word': 167,
#          'heiress': 1,
#          'disney': 28,
#          'empire': 7,
#          'know': 218,
#          'gop': 807,
#          'scammed': 9,
#          'shred': 64,
#          'tax': 202,
#          'bill': 605,
#          'tone': 4,
#          'deaf': 6,
#          'congrats': 3,
#          'rep': 154,
#          'scalise': 20,
#          'losing': 49,
#          'weight': 8,
#          'almost': 23,
#          'died': 29,
#          'brutally': 76,
#          'mock': 140,
#          'robot': 10,
#          'hall': 60,
#          'president': 1165,
#          'mueller': 79,
#          'spokesman': 9,
#          'f': 299,
#          'cked': 10,
#          'snl': 61,
#          'hilariously': 129,
#          'accused': 53,
#          'child': 241,
#          'molester': 8,
#          'roy': 64,
#          'moore': 98,
#          'al': 113,
#          'senate': 175,
#          'race': 212,
#          'video': 3409,
#          'republican': 867,
#          'senator': 312,
#          'get': 980,
#          'dragged': 17,
#          'going': 255,
#          'robert': 59,
#          'heartless': 12,
#          'rebuke': 13,
#          'victim': 220,
#          'invite': 23,
#          'nra': 75,
#          'xmas': 1,
#          'party': 291,
#          'sandy': 12,
#          'hook': 14,
#          'anniversary': 17,
#          'ky': 8,
#          'commits': 3,
#          'suicide': 36,
#          'allegation': 42,
#          'molested': 5,
#          'teen': 99,
#          'girl': 205,
#          'detail': 279,
#          'meghan': 11,
#          'mccain': 127,
#          'amazing': 56,
#          'response': 241,
#          'doug': 6,
#          'jones': 53,
#          'win': 265,
#          'deep': 58,
#          'red': 65,
#          'cnn': 542,
#          'call': 606,
#          'democrat': 771,
#          'represent': 14,
#          'first': 343,
#          'time': 442,
#          'white': 904,
#          'house': 559,
#          'sexist': 47,
#          'slut': 5,
#          'shame': 59,
#          'sen': 24,
#          'kirsten': 1,
#          'gillibrand': 5,
#          'despicable': 12,
#          'female': 144,
#          'would': 261,
#          'anything': 33,
#          'campaign': 479,
#          'money': 202,
#          'molesting': 4,
#          'candidate': 250,
#          'side': 49,
#          'putin': 152,
#          'reagan': 55,
#          'fox': 451,
#          'host': 394,
#          'cleansing': 4,
#          'arrest': 66,
#          'everyone': 86,
#          'investigating': 23,
#          'liberal': 549,
#          'group': 223,
#          'troll': 72,
#          'rally': 324,
#          'best': 150,
#          'possible': 55,
#          'way': 224,
#          'jr': 104,
#          'try': 196,
#          'franken': 16,
#          'resignation': 15,
#          'backfire': 48,
#          'immediately': 38,
#          'breaking': 896,
#          'finally': 127,
#          'due': 26,
#          'walter': 6,
#          'scott': 57,
#          'killer': 58,
#          'sentenced': 6,
#          'prison': 72,
#          'proof': 94,
#          'unfit': 18,
#          'service': 100,
#          'completely': 48,
#          'screw': 27,
#          'middle': 87,
#          'east': 31,
#          'peace': 38,
#          'process': 26,
#          'another': 169,
#          'wednesday': 1,
#          'recognizing': 1,
#          'jerusalem': 14,
#          'today': 103,
#          'supporting': 78,
#          'coal': 36,
#          'ceo': 85,
#          'upset': 14,
#          'wiping': 1,
#          'thousand': 69,
#          'mining': 3,
#          'job': 263,
#          'sitting': 13,
#          'enough': 45,
#          'donates': 10,
#          'national': 216,
#          'committee': 41,
#          'better': 73,
#          'pedophile': 19,
#          'eating': 15,
#          'habit': 7,
#          'could': 243,
#          'dramatically': 3,
#          'affecting': 3,
#          'wellbeing': 1,
#          'safety': 19,
#          'wanted': 55,
#          'twitter': 384,
#          'follower': 20,
#          'plan': 302,
#          'backfired': 8,
#          'miserably': 15,
#          'sarah': 140,
#          'huckabee': 44,
#          'sander': 339,
#          'attacking': 51,
#          'aged': 4,
#          'well': 56,
#          'agent': 109,
#          'destroy': 134,
#          'attack': 504,
#          'agency': 32,
#          'ghost': 4,
#          'flipped': 4,
#          'hilarious': 264,
#          'skit': 16,
#          'take': 435,
#          'private': 80,
#          'holiday': 8,
#          'hell': 106,
#          'leaked': 65,
#          'email': 287,
#          'prof': 152,
#          'official': 176,
#          'aware': 8,
#          'russia': 376,
#          'thrown': 15,
#          'usa': 68,
#          'election': 511,
#          'admitted': 24,
#          'knew': 46,
#          'flynn': 84,
#          'lied': 95,
#          'asked': 155,
#          'drop': 159,
#          'awesome': 130,
#          'mashup': 3,
#          'michael': 82,
#          'leading': 28,
#          'lock': 31,
#          'chant': 49,
#          'go': 673,
#          'court': 277,
#          'panic': 37,
#          'knowing': 7,
#          'crack': 21,
#          'testify': 20,
#          'epic': 133,
#          'ck': 141,
#          'britain': 25,
#          'supremacist': 83,
#          'retweets': 14,
#          'show': 659,
#          'voter': 329,
#          'avoid': 26,
#          'scandalous': 3,
#          'elected': 71,
#          'joe': 145,
#          'scarborough': 22,
#          'imagination': 2,
#          'really': 217,
#          'mind': 56,
#          'source': 38,
#          'confirm': 28,
#          'interviewed': 14,
#          'jared': 26,
#          'kushner': 32,
#          'several': 37,
#          'week': 106,
#          'ago': 59,
#          'crazy': 121,
#          'wrong': 100,
#          'account': 46,
#          'sh': 117,
#          'world': 246,
#          'leader': 228,
#          'remark': 62,
#          'american': 771,
#          'raping': 27,
#          'old': 377,
#          'biggest': 61,
#          'kkk': 71,
#          'fan': 158,
#          'loved': 5,
#          'anti': 609,
#          'muslim': 842,
#          'morning': 67,
#          'spent': 33,
#          'night': 115,
#          'retweeting': 2,
#          'convicted': 23,
#          'criminal': 106,
#          'sean': 148,
#          'hannity': 95,
#          'throwing': 17,
#          'stage': 86,
#          'temper': 27,
#          'tantrum': 51,
#          'photo': 146,
#          'posed': 6,
#          'give': 434,
#          'big': 223,
#          'insane': 113,
#          'rant': 131,
#          'wake': 31,
#          'scream': 51,
#          'hurling': 3,
#          'racial': 29,
#          'slur': 14,
#          'yesterday': 6,
#          'supporter': 643,
#          'object': 7,
#          'prince': 27,
#          'harry': 47,
#          'recent': 11,
#          'engagement': 1,
#          'terrible': 24,
#          'reason': 221,
#          'honoring': 11,
#          'native': 14,
#          'code': 16,
#          'talker': 3,
#          'elizabeth': 94,
#          'warren': 117,
#          'pocahontas': 14,
#          'using': 148,
#          'picture': 97,
#          'look': 155,
#          'popular': 57,
#          'breitbart': 50,
#          'editor': 34,
#          'song': 42,
#          'ringo': 2,
#          'starr': 4,
#          'pedo': 4,
#          'photographer': 9,
#          'trolling': 16,
#          'whole': 31,
#          'level': 33,
#          'golfing': 11,
#          'vacay': 2,
#          'done': 60,
#          'ever': 188,
#          'two': 200,
#          'still': 119,
#          'defends': 74,
#          'principle': 5,
#          'power': 78,
#          'need': 259,
#          'right': 459,
#          'remain': 10,
#          'relevant': 3,
#          'everything': 43,
#          'heard': 11,
#          'access': 29,
#          'hollywood': 162,
#          'tape': 52,
#          'never': 212,
#          'happened': 83,
#          'blister': 5,
#          'representation': 2,
#          'wrecked': 18,
#          'yelling': 8,
#          'magazine': 34,
#          'calling': 135,
#          'lie': 367,
#          'humiliates': 82,
#          'award': 53,
#          'ivanka': 122,
#          'malia': 21,
#          'dad': 90,
#          'stop': 257,
#          'baboon': 2,
#          'trumpsters': 1,
#          'launch': 42,
#          'conspiracy': 92,
#          'theory': 41,
#          'boot': 19,
#          'foot': 18,
#          'gay': 180,
#          'operative': 37,
#          'endorses': 37,
#          'bigoted': 21,
#          'deviant': 2,
#          'retired': 11,
#          'keep': 130,
#          'away': 149,
#          'high': 129,
#          'school': 322,
#          'cheerleader': 10,
#          'york': 103,
#          'report': 295,
#          'actual': 34,
#          'congress': 157,
#          'ban': 225,
#          'gene': 2,
#          'simmons': 3,
#          'life': 341,
#          'harassing': 7,
#          'staff': 49,
#          'camera': 53,
#          'nicolle': 6,
#          'wallace': 24,
#          'woodshed': 24,
#          'backing': 15,
#          'pastor': 82,
#          'full': 132,
#          'qaeda': 23,
#          'defending': 60,
#          'purity': 1,
#          'security': 191,
#          'adviser': 52,
#          'reportedly': 61,
#          'trashed': 12,
#          'favorite': 22,
#          'channel': 16,
#          'soothe': 1,
#          'battered': 1,
#          'ego': 14,
#          'taken': 47,
#          'cleaner': 3,
#          'texas': 163,
#          'governor': 165,
#          'broke': 59,
#          'unprecedented': 25,
#          'conservative': 384,
#          'christian': 173,
#          'kept': 24,
#          'sexual': 162,
#          'assault': 133,
#          'secret': 236,
#          'lawmaker': 85,
#          'caught': 272,
#          'hot': 58,
#          'mic': 53,
#          'trashing': 18,
#          'destroying': 26,
#          'country': 179,
#          'reputation': 6,
#          'got': 260,
#          'p': 54,
#          'ssy': 13,
#          'handed': 50,
#          'zealand': 1,
#          'prime': 30,
#          'minister': 46,
#          'chaos': 41,
#          'ensues': 8,
#          'man': 428,
#          'accidentally': 58,
#          'shoot': 89,
#          'wife': 146,
#          'church': 89,
#          'gun': 488,
#          'talk': 80,
#          'accuser': 41,
#          'confirms': 44,
#          'banned': 39,
#          'mall': 26,
#          'asking': 67,
#          'snitch': 5,
#          'getting': 101,
#          'trolled': 15,
#          'hard': 101,
#          'admin': 20,
#          'toss': 2,
#          'rule': 102,
#          'son': 160,
#          'worse': 77,
#          'douchebags': 1,
#          'light': 33,
#          'pentagon': 22,
#          'resign': 34,
#          'busted': 180,
#          'inappropriate': 12,
#          'relation': 15,
#          'mocked': 29,
#          'marco': 43,
#          'rubio': 81,
#          'drinking': 9,
#          'water': 168,
#          'came': 33,
#          'haunt': 4,
#          'corporate': 20,
#          'shock': 42,
#          'economic': 42,
#          'truth': 226,
#          'cut': 137,
#          'threatens': 167,
#          'jail': 80,
#          'truck': 49,
#          'owner': 137,
#          'sticker': 13,
#          'screenshots': 74,
#          'delusional': 34,
#          'reporting': 22,
#          'fact': 112,
#          'uranium': 27,
#          'one': 641,
#          'deal': 176,
#          'loses': 90,
#          'extremist': 30,
#          'story': 214,
#          'press': 205,
#          'air': 100,
#          'force': 152,
#          'least': 23,
#          'perverted': 8,
#          'oops': 112,
#          'judicial': 18,
#          'nominee': 86,
#          'tell': 453,
#          'marriage': 40,
#          'attorney': 103,
#          'laugh': 75,
#          'philippine': 9,
#          'journalist': 77,
#          'spy': 48,
#          'routinely': 2,
#          'murdered': 68,
#          'biden': 87,
#          'six': 24,
#          'document': 64,
#          'prove': 71,
#          'took': 72,
#          'laundered': 1,
#          'bank': 48,
#          'corner': 11,
#          'lobbyist': 10,
#          'help': 206,
#          'raging': 7,
#          'b': 54,
#          'ner': 1,
#          'colleague': 13,
#          'liked': 4,
#          'dating': 6,
#          'teenage': 17,
#          'condemns': 13,
#          'nazi': 99,
#          'misconduct': 8,
#          'throw': 101,
#          'intelligence': 70,
#          'community': 90,
#          'bus': 43,
#          'despite': 26,
#          'strong': 14,
#          'evidence': 108,
#          'meddling': 17,
#          'mike': 116,
#          'penny': 108,
#          'sure': 34,
#          'uncomfortable': 9,
#          'g': 20,
#          'maga': 11,
#          'mean': 56,
#          'grope': 4,
#          'molestation': 2,
#          'ok': 20,
#          'consensual': 2,
#          'newsweek': 17,
#          'made': 201,
#          'cover': 90,
#          'freaking': 15,
#          'defended': 18,
#          'pedophilia': 9,
#          'bible': 19,
#          'turn': 141,
#          'disgusting': 125,
#          'sneaking': 1,
#          'around': 67,
#          'behind': 123,
#          'unravel': 1,
#          'administration': 88,
#          'sunday': 84,
#          'massacre': 45,
#          'bumped': 2,
#          'columbine': 3,
#          'top': 239,
#          'ten': 31,
#          'deadliest': 2,
#          'mass': 83,
#          'shooting': 171,
#          'barely': 6,
#          'spends': 13,
#          'second': 91,
#          'last': 160,
#          'drubbing': 1,
#          'revisits': 1,
#          'victory': 62,
#          'instead': 46,
#          'maine': 27,
#          'expand': 7,
#          'medicaid': 12,
#          'rick': 43,
#          'santorum': 11,
#          'torch': 23,
#          'taking': 80,
#          'responsibility': 8,
#          'electoral': 36,
#          'bloodbath': 5,
#          'seething': 4,
#          'humiliating': 24,
#          'virginia': 45,
#          'ed': 16,
#          'gillespie': 3,
#          'resistance': 11,
#          'gave': 123,
#          'huge': 229,
#          'justice': 165,
#          'dept': 39,
#          'realizes': 5,
#          'prosecuting': 2,
#          'woman': 699,
#          'laughing': 41,
#          'stupid': 97,
#          'case': 129,
#          'entirely': 8,
#          'dumba': 1,
#          'promoting': 13,
#          'day': 407,
#          'third': 54,
#          'war': 390,
#          'agrees': 24,
#          'treated': 17,
#          'harshly': 1,
#          'milking': 1,
#          'miss': 46,
#          'unexpected': 11,
#          'answer': 126,
#          'furious': 94,
#          'trying': 134,
#          'facebook': 146,
#          'personal': 21,
#          'info': 59,
#          'criticize': 12,
#          'multiple': 31,
#          'pee': 14,
#          'real': 174,
#          'completed': 2,
#          'transformation': 11,
#          'safe': 36,
#          'space': 34,
#          'fragile': 5,
#          'snowflakey': 1,
#          'japanese': 6,
#          'diplomat': 14,
#          'many': 47,
#          'latest': 128,
#          'god': 75,
#          'answering': 3,
#          'prayer': 35,
#          'letting': 21,
#          'shot': 150,
#          'university': 82,
#          'police': 395,
#          'kick': 45,
#          'humiliated': 69,
#          'campus': 68,
#          'start': 85,
#          'trouble': 23,
#          'lawyer': 138,
#          'bomb': 99,
#          'alleges': 1,
#          'direct': 15,
#          'pay': 158,
#          'play': 104,
#          'attempt': 107,
#          'claim': 333,
#          'forcing': 26,
#          'baby': 125,
#          'economy': 39,
#          'someone': 39,
#          'tried': 79,
#          'cash': 40,
#          'antifa': 89,
#          'jacket': 4,
#          'field': 28,
#          'delivers': 58,
#          'scathing': 32,
#          'reminder': 5,
#          'classic': 18,
#          'went': 71,
#          'japan': 12,
#          'proved': 18,
#          'zilch': 1,
#          'missile': 27,
#          'work': 132,
#          'wall': 181,
#          'close': 51,
#          'disgraced': 15,
#          'face': 206,
#          'indictment': 16,
#          'team': 128,
#          'watergate': 15,
#          'prosecutor': 28,
#          'gag': 10,
#          'link': 18,
#          'abortion': 113,
#          'bizarre': 58,
#          'horribly': 8,
#          'offensive': 40,
#          'hawaiian': 7,
#          'perfect': 116,
#          'sign': 111,
#          'infuriate': 7,
#          'landed': 6,
#          'want': 458,
#          'supreme': 168,
#          'punish': 30,
#          'hypocrite': 76,
#          'end': 147,
#          'harassment': 46,
#          'predator': 37,
#          'pulling': 16,
#          'nfl': 161,
#          'related': 18,
#          'unlikely': 9,
#          'sponsor': 15,
#          'special': 73,
#          'gift': 32,
#          'mail': 96,
#          'every': 141,
#          'month': 96,
#          'probably': 25,
#          'burn': 89,
#          'congressman': 117,
#          'admits': 138,
#          'constituent': 15,
#          'hero': 61,
#          'celebrate': 26,
#          'shredded': 9,
#          'l': 20,
#          'twisting': 3,
#          'brilliant': 123,
#          'energy': 28,
#          'secretary': 97,
#          'idea': 55,
#          'stopping': 2,
#          'jeff': 61,
#          'session': 99,
#          'oh': 41,
#          'contact': 10,
#          'remember': 52,
#          'alt': 40,
#          'reporter': 291,
#          'fooled': 4,
#          'fake': 401,
#          'upcoming': 12,
#          'civil': 72,
#          'amendment': 64,
#          'tty': 5,
#          'pizza': 15,
#          'small': 32,
#          'fortune': 11,
#          'literally': 82,
#          'sabotaging': 1,
#          'nyc': 129,
#          'terrorist': 374,
#          'keeping': 18,
#          'mouth': 26,
#          'shut': 142,
#          'little': 84,
#          'known': 35,
#          'aide': 64,
#          'dangerous': 77,
#          'manafort': 16,
#          'ambassador': 45,
#          'accuses': 51,
#          'violating': 9,
#          'constitution': 40,
#          'visit': 91,
#          'dumbass': 7,
#          'meme': 24,
#          'hillary': 2310,
#          'fistfighting': 1,
#          'jesus': 39,
#          'chuck': 64,
#          'schumer': 57,
#          'nuked': 1,
#          'blaming': 45,
#          'knock': 29,
#          'flag': 222,
#          'dodge': 9,
#          'question': 191,
#          'chief': 142,
#          'kelly': 115,
#          'think': 216,
#          'slavery': 30,
#          'legal': 74,
#          'claiming': 43,
#          'crime': 91,
#          'refers': 10,
#          'clinton': 1175,
#          'unhinged': 72,
#          'seth': 70,
#          'meyers': 19,
#          'summed': 1,
#          'monday': 13,
#          'event': 94,
#          'perfectly': 77,
#          'knife': 25,
#          'birthday': 25,
#          'must': 152,
#          'guilty': 42,
#          'gate': 17,
#          'enter': 14,
#          'plea': 11,
#          'scandal': 134,
#          'considered': 18,
#          'else': 23,
#          'covered': 10,
#          'camp': 40,
#          'manager': 84,
#          'head': 173,
#          'explode': 40,
#          'find': 106,
#          'higher': 8,
#          'pardon': 13,
#          'anyone': 67,
#          'indicted': 14,
#          'move': 100,
#          'fire': 170,
#          'probe': 52,
#          'number': 125,
#          'insurer': 3,
#          'trainwreck': 2,
#          'fault': 18,
#          'rib': 1,
#          'obsession': 25,
#          'impeaching': 6,
#          'wreck': 15,
#          'tomi': 35,
#          'lahren': 36,
#          'halloween': 27,
#          'costume': 9,
#          'violates': 7,
#          'something': 107,
#          'totally': 61,
#          'rubbed': 1,
#          'rumor': 8,
#          'orange': 10,
#          'major': 180,
#          'ally': 36,
#          'looking': 34,
#          'irritate': 1,
#          'tip': 18,
#          'charge': 100,
#          'filed': 8,
#          'puerto': 32,
#          'rico': 26,
#          'contract': 7,
#          'company': 114,
#          'corrupt': 55,
#          'executed': 6,
#          'closed': 9,
#          'coordinate': 1,
#          'sanction': 19,
#          'yet': 99,
#          'asshole': 3,
#          'rammed': 1,
#          'bunch': 17,
#          'protester': 276,
#          'car': 74,
#          'judge': 298,
#          'barred': 6,
#          'mom': 90,
#          'seeing': 21,
#          'unpaid': 3,
#          'fee': 17,
#          'resigns': 22,
#          'place': 98,
#          'proposed': 7,
#          'melania': 116,
#          'lewis': 28,
#          'milo': 11,
#          'yiannopoulos': 4,
#          'aussie': 1,
#          'vote': 433,
#          'equality': 17,
#          'wedding': 14,
#          'ice': 28,
#          'thug': 136,
#          'ambulance': 8,
#          'cerebral': 1,
#          'palsy': 1,
#          'surgery': 16,
#          'lover': 7,
#          'kill': 181,
#          'amazingly': 10,
#          'created': 28,
#          'hit': 156,
#          'serious': 47,
#          'telling': 78,
#          'kid': 226,
#          'respect': 33,
#          'wet': 3,
#          'pant': 17,
#          'bob': 13,
#          'corker': 4,
#          'alert': 42,
#          'daycare': 7,
#          'angry': 130,
#          'bone': 3,
#          'spur': 1,
#          'draft': 11,
#          'deferment': 1,
#          'soldier': 72,
#          'widow': 24,
#          'speaks': 77,
#          'cry': 65,
#          'liar': 76,
#          'nursing': 1,
#          'textbook': 5,
#          'recalled': 2,
#          'apology': 41,
#          'issued': 16,
#          'stereotype': 2,
#          'pain': 4,
#          'management': 8,
#          'poll': 200,
#          'ripped': 32,
#          'apart': 59,
#          ...})

# %%
# Print the most common lemmatized words and their frequencies
print(fake_text_freq.most_common(10))
# Out:
# [('trump', 79369), ('said', 33760), ('president', 28269), ('people', 26621), ('one', 25382), ('u', 24484), ('state', 23625), ('would', 23550), ('clinton', 19778), ('time', 19199)]

# %%
print(fake_title_freq.most_common(10))
# Out:
# [('trump', 9349), ('video', 3409), ('obama', 2581), ('hillary', 2310), ('watch', 1932), ('clinton', 1175), ('president', 1165), ('u', 1148), ('get', 980), ('black', 973)]

# %%
all_true_lemmatized_text = [token for tokens_list in df_true["text_tokens"] for token in tokens_list]
all_true_lemmatized_title = [token for tokens_list in df_true["title_tokens"] for token in tokens_list]

# %%
# Count the frequency of each lemmatized word
true_text_freq = Counter(all_true_lemmatized_text)
true_title_freq = Counter(all_true_lemmatized_title)

# %%
# Print the most common lemmatized words and their frequencies
print(true_text_freq.most_common(10))
# Out:
# [('said', 97866), ('trump', 54115), ('u', 46534), ('state', 37225), ('would', 31240), ('reuters', 28674), ('president', 28418), ('republican', 22862), ('year', 22354), ('government', 19681)]

# %%
print(true_title_freq.most_common(10))
# Out:
# [('trump', 5523), ('u', 4688), ('say', 3200), ('house', 1449), ('republican', 972), ('russia', 967), ('north', 912), ('korea', 887), ('new', 871), ('state', 819)]

# %%
from wordcloud import WordCloud

# Create a WordCloud object
wordcloud = WordCloud(width=3000, height=2000, background_color='black').generate_from_frequencies(fake_text_freq)

# Display the generated word cloud
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Fake Lemmatized Words')
plt.show()
#wordcloud.to_file("fake.png")

# %%
# Create a WordCloud object
wordcloud = WordCloud(width=3000, height=2000, background_color='black').generate_from_frequencies(true_text_freq)

# Display the generated word cloud
plt.figure(figsize=(40, 20))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of True Lemmatized Words')
plt.show()
#wordcloud.to_file("true.png")

# %% [markdown]
# ### Unigrams

# %%
# Get the most common 20 words and their frequencies
most_fake_common_words = fake_text_freq.most_common(20)
most_fake_common_words, frequencies = zip(*most_fake_common_words)

# Plot the most common words and their frequencies
plt.figure(figsize=(8, 4))
plt.bar(most_fake_common_words, frequencies)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 20 Most Common Words in Fake Data')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Get the most common 20 words and their frequencies
most_true_common_words = true_text_freq.most_common(20)
most_true_common_words, frequencies = zip(*most_true_common_words)

# Plot the most common words and their frequencies
plt.figure(figsize=(8, 4))
plt.bar(most_true_common_words, frequencies)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 20 Most Common Words in True Data')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bigrams

# %%
bigram_lists = [list(ngrams(tokens, 2)) for tokens in df_fake['text_tokens']]
# Flatten the list of bigrams
all_bigrams = [bigram for bigrams_list in bigram_lists for bigram in bigrams_list]
# Count the occurrences of each bigram
bigram_counts = Counter(all_bigrams)

# Get the most common bigrams
most_common_bigrams = bigram_counts.most_common(10)  
# Extract labels and counts from most_common_bigrams
bigram_labels = [' '.join(bigram) for bigram, _ in most_common_bigrams]
bigram_counts = [count for _, count in most_common_bigrams]


# Create a gradient of rainbow colors
num_colors = len(bigram_labels)
colors = plt.cm.rainbow(np.linspace(0, 1, num_colors))

# Create a horizontal bar plot for most common bigrams with rainbow colors
plt.figure(figsize=(8, 4))
bars = plt.barh(bigram_labels, bigram_counts, color=colors)

# Adding labels and counts on the bars
for bar, count in zip(bars, bigram_counts):
    plt.text(bar.get_width() + 10, bar.get_y() + bar.get_height()/2, str(count), va='center')

plt.xlabel('Count')
plt.ylabel('Bigrams')
plt.title('Most Common Bigrams in Fake Data')
plt.gca().invert_yaxis()  # Invert y-axis to have the highest count at the top
plt.tight_layout()
plt.show()

# %%
bigram_lists = [list(ngrams(tokens, 2)) for tokens in df_true['text_tokens']]
# Flatten the list of bigrams
all_bigrams = [bigram for bigrams_list in bigram_lists for bigram in bigrams_list]
# Count the occurrences of each bigram
bigram_counts = Counter(all_bigrams)

# Get the most common bigrams
most_common_bigrams = bigram_counts.most_common(10)  
# Extract labels and counts from most_common_bigrams
bigram_labels = [' '.join(bigram) for bigram, _ in most_common_bigrams]
bigram_counts = [count for _, count in most_common_bigrams]


# Create a gradient of rainbow colors
num_colors = len(bigram_labels)
colors = plt.cm.rainbow(np.linspace(0, 1, num_colors))

# Create a horizontal bar plot for most common bigrams with rainbow colors
plt.figure(figsize=(8,4))
bars = plt.barh(bigram_labels, bigram_counts, color=colors)

# Adding labels and counts on the bars
for bar, count in zip(bars, bigram_counts):
    plt.text(bar.get_width() + 10, bar.get_y() + bar.get_height()/2, str(count), va='center')

plt.xlabel('Count')
plt.ylabel('Bigrams')
plt.title('Most Common Bigrams in True Data')
plt.gca().invert_yaxis()  # Invert y-axis to have the highest count at the top
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Trigrams

# %%
trigram_lists = [list(ngrams(tokens, 3)) for tokens in df_fake['text_tokens']]
all_trigrams = [trigram for trigrams_list in trigram_lists for trigram in trigrams_list]
# Count the occurrences of each trigram
trigram_counts = Counter(all_trigrams)

most_common_trigrams = trigram_counts.most_common(20)  
trigram_labels = [' '.join(trigram) for trigram, _ in most_common_trigrams]
trigram_counts = [count for _, count in most_common_trigrams]

# Create a vertical bar plot for most common trigrams
plt.figure(figsize=(8, 4))
plt.bar(trigram_labels, trigram_counts)
plt.xticks(rotation=45, ha='right')
plt.xlabel('trigrams')
plt.ylabel('Count')
plt.title('Most Common trigrams in Fake Data')
plt.tight_layout()
plt.show()

# %%
trigram_lists = [list(ngrams(tokens, 3)) for tokens in df_true['text_tokens']]
all_trigrams = [trigram for trigrams_list in trigram_lists for trigram in trigrams_list]
# Count the occurrences of each trigram
trigram_counts = Counter(all_trigrams)

most_common_trigrams = trigram_counts.most_common(20)  
trigram_labels = [' '.join(trigram) for trigram, _ in most_common_trigrams]
trigram_counts = [count for _, count in most_common_trigrams]

# Create a vertical bar plot for most common trigrams
plt.figure(figsize=(8, 4))
plt.bar(trigram_labels, trigram_counts)
plt.xticks(rotation=45, ha='right')
plt.xlabel('trigrams')
plt.ylabel('Count')
plt.title('Most Common trigrams in True Data')
plt.tight_layout()
plt.show()

# %%
# Remove extra spaces and convert tokens back to a string
df_fake["text_tokens"] = df_fake["text_tokens"].apply(lambda x: ' '.join(token.strip() for token in x))
df_fake["title_tokens"] = df_fake["title_tokens"].apply(lambda x: ' '.join(token.strip() for token in x))
df_true["text_tokens"] = df_true["text_tokens"].apply(lambda x: ' '.join(token.strip() for token in x))
df_true["title_tokens"] = df_true["title_tokens"].apply(lambda x: ' '.join(token.strip() for token in x))

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   donald trump sends out embarrassing new year ...
# 1   drunk bragging trump staffer started russian ...
# 2   sheriff david clarke becomes an internet joke...
# 3   trump is so obsessed he even has obama s name...
# 4   pope francis just called out donald trump dur...
#
#                                                 text subject       date  \
# 0  donald trump just couldn t wish all americans ...    News 2017-12-31
# 1  house intelligence committee chairman devin nu...    News 2017-12-31
# 2  on friday  it was revealed that former milwauk...    News 2017-12-30
# 3  on christmas day  donald trump announced that ...    News 2017-12-29
# 4  pope francis used his annual christmas day mes...    News 2017-12-25
#
#    class                                        text_tokens  \
# 0      0  donald trump wish american happy new year leav...
# 1      0  house intelligence committee chairman devin nu...
# 2      0  friday revealed former milwaukee sheriff david...
# 3      0  christmas day donald trump announced would bac...
# 4      0  pope francis used annual christmas day message...
#
#                                         title_tokens
# 0  donald trump sends embarrassing new year eve m...
# 1  drunk bragging trump staffer started russian c...
# 2  sheriff david clarke becomes internet joke thr...
# 3  trump obsessed even obama name coded website i...
# 4  pope francis called donald trump christmas speech

# %%
df_true.head()
# Out:
#                                                title  \
# 0  as u s  budget fight looms  republicans flip t...
# 1  u s  military to accept transgender recruits o...
# 2  senior u s  republican senator   let mr  muell...
# 3  fbi russia probe helped by australian diplomat...
# 4  trump wants postal service to charge  much mor...
#
#                                                 text       subject       date  \
# 0  washington  reuters    the head of a conservat...  politicsNews 2017-12-31
# 1  washington  reuters    transgender people will...  politicsNews 2017-12-29
# 2  washington  reuters    the special counsel inv...  politicsNews 2017-12-31
# 3  washington  reuters    trump campaign adviser ...  politicsNews 2017-12-30
# 4  seattle washington  reuters    president donal...  politicsNews 2017-12-29
#
#    class                                        text_tokens  \
# 0      1  washington reuters head conservative republica...
# 1      1  washington reuters transgender people allowed ...
# 2      1  washington reuters special counsel investigati...
# 3      1  washington reuters trump campaign adviser geor...
# 4      1  seattle washington reuters president donald tr...
#
#                                         title_tokens
# 0  u budget fight loom republican flip fiscal script
# 1  u military accept transgender recruit monday p...
# 2     senior u republican senator let mr mueller job
# 3  fbi russia probe helped australian diplomat ti...
# 4  trump want postal service charge much amazon s...

# %%
df = pd.concat([df_fake,df_true], ignore_index = True)

# %%
df.head()
# Out:
#                                                title  \
# 0   donald trump sends out embarrassing new year ...
# 1   drunk bragging trump staffer started russian ...
# 2   sheriff david clarke becomes an internet joke...
# 3   trump is so obsessed he even has obama s name...
# 4   pope francis just called out donald trump dur...
#
#                                                 text subject       date  \
# 0  donald trump just couldn t wish all americans ...    News 2017-12-31
# 1  house intelligence committee chairman devin nu...    News 2017-12-31
# 2  on friday  it was revealed that former milwauk...    News 2017-12-30
# 3  on christmas day  donald trump announced that ...    News 2017-12-29
# 4  pope francis used his annual christmas day mes...    News 2017-12-25
#
#    class                                        text_tokens  \
# 0      0  donald trump wish american happy new year leav...
# 1      0  house intelligence committee chairman devin nu...
# 2      0  friday revealed former milwaukee sheriff david...
# 3      0  christmas day donald trump announced would bac...
# 4      0  pope francis used annual christmas day message...
#
#                                         title_tokens
# 0  donald trump sends embarrassing new year eve m...
# 1  drunk bragging trump staffer started russian c...
# 2  sheriff david clarke becomes internet joke thr...
# 3  trump obsessed even obama name coded website i...
# 4  pope francis called donald trump christmas speech

# %%
df['class'].value_counts()
# Out:
# 0    23478
# 1    21210
# Name: class, dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [title, text, subject, date, class, text_tokens, title_tokens]
# Index: []

# %%
#Shuffling of Data
df = df.sample(frac=1.0, random_state=42)
df.head()
# Out:
#                                                    title  \
# 17893  wow  leftist librarian rejects shipment of chi...
# 39481  kenya opposition leader calls for calm in slum...
# 36272  egypt rejects u s  decision to move its embass...
# 21761   audio nation of islam leader farrakhan   we w...
# 7557    trump rally nearly turns into a full blown ra...
#
#                                                     text    subject  \
# 17893  a school librarian in cambridge  massachusetts...  left-news
# 39481  nairobi  reuters    kenyan opposition leader r...  worldnews
# 36272  cairo  reuters    egypt rejected the u s  deci...  worldnews
# 21761  after a recent speech given by minister louis ...  left-news
# 7557   tensions ran high outside of a campaign rally ...       News
#
#             date  class                                        text_tokens  \
# 17893 2017-09-28      0  school librarian cambridge massachusetts rejec...
# 39481 2017-10-29      1  nairobi reuters kenyan opposition leader raila...
# 36272 2017-12-06      1  cairo reuters egypt rejected u decision move e...
# 21761 2015-05-08      0  recent speech given minister louis farrakhan t...
# 7557  2016-03-11      0  tension ran high outside campaign rally donald...
#
#                                             title_tokens
# 17893  wow leftist librarian reject shipment child bo...
# 39481  kenya opposition leader call calm slum hit dea...
# 36272  egypt reject u decision move embassy jerusalem...
# 21761      audio nation islam leader farrakhan kill go u
# 7557   trump rally nearly turn full blown race war st...

# %%
df['title_tokens'][0]
# Out:
# 'donald trump sends embarrassing new year eve message disturbing'

# %%
# Concatenate the values of the 'text' and 'title' columns and create a new column
df['input_text'] = df['title_tokens'] + ' ' + df['text_tokens']

# %%
df.head()
# Out:
#                                                    title  \
# 17893  wow  leftist librarian rejects shipment of chi...
# 39481  kenya opposition leader calls for calm in slum...
# 36272  egypt rejects u s  decision to move its embass...
# 21761   audio nation of islam leader farrakhan   we w...
# 7557    trump rally nearly turns into a full blown ra...
#
#                                                     text    subject  \
# 17893  a school librarian in cambridge  massachusetts...  left-news
# 39481  nairobi  reuters    kenyan opposition leader r...  worldnews
# 36272  cairo  reuters    egypt rejected the u s  deci...  worldnews
# 21761  after a recent speech given by minister louis ...  left-news
# 7557   tensions ran high outside of a campaign rally ...       News
#
#             date  class                                        text_tokens  \
# 17893 2017-09-28      0  school librarian cambridge massachusetts rejec...
# 39481 2017-10-29      1  nairobi reuters kenyan opposition leader raila...
# 36272 2017-12-06      1  cairo reuters egypt rejected u decision move e...
# 21761 2015-05-08      0  recent speech given minister louis farrakhan t...
# 7557  2016-03-11      0  tension ran high outside campaign rally donald...
#
#                                             title_tokens  \
# 17893  wow leftist librarian reject shipment child bo...
# 39481  kenya opposition leader call calm slum hit dea...
# 36272  egypt reject u decision move embassy jerusalem...
# 21761      audio nation islam leader farrakhan kill go u
# 7557   trump rally nearly turn full blown race war st...
#
#                                               input_text
# 17893  wow leftist librarian reject shipment child bo...
# 39481  kenya opposition leader call calm slum hit dea...
# 36272  egypt reject u decision move embassy jerusalem...
# 21761  audio nation islam leader farrakhan kill go u ...
# 7557   trump rally nearly turn full blown race war st...

# %%
len(df['title_tokens'][0]) , len(df['text_tokens'][0]), len(df['input_text'][0])
# Out:
# (63, 1734, 1798)

# %%
df = df.drop(['title','text','subject','date'], axis = 1)

# %%
df = df.drop(['text_tokens','title_tokens'], axis = 1)

# %%
df.head()
# Out:
#        class                                         input_text
# 17893      0  wow leftist librarian reject shipment child bo...
# 39481      1  kenya opposition leader call calm slum hit dea...
# 36272      1  egypt reject u decision move embassy jerusalem...
# 21761      0  audio nation islam leader farrakhan kill go u ...
# 7557       0  trump rally nearly turn full blown race war st...

# %%
df['class'].value_counts()
# Out:
# 0    23478
# 1    21210
# Name: class, dtype: int64

# %% [markdown]
# ### Train Test Spliting

# %%
X = df['input_text']
Y = df['class']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.33,random_state=40)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((29940,), (14748,), (29940,), (14748,))

# %% [markdown]
# ## Feature Extraction : Vectorization

# %%
vectorizer = TfidfVectorizer()
X_train_vectorized = vectorizer.fit_transform(X_train)
X_text_vectorized = vectorizer.transform(X_test)

# %% [markdown]
# ## Model Building :

# %% [markdown]
# ###  1. Random Forest Classifier

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train_vectorized,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_train_predictions = rf_classifier.predict(X_train_vectorized)

# %%
rf_test_predictions = rf_classifier.predict(X_text_vectorized)

# %%
print(" Confusion Matrix For the Train Data: ")
confusion_matrix(Y_train,rf_train_predictions)
# Out:
#  Confusion Matrix For the Train Data:
# array([[15827,     0],
#        [    0, 14113]], dtype=int64)

# %%
print(" Confusion Matrix For the Test Data: ")
confusion_matrix(Y_test,rf_test_predictions)
# Out:
#  Confusion Matrix For the Test Data:
# array([[7604,   47],
#        [  67, 7030]], dtype=int64)

# %%
rf_train_accuracy = accuracy_score(Y_train,rf_train_predictions)
rf_test_accuracy = accuracy_score(Y_test,rf_test_predictions)

# %%
print(" Random Forest Model Accuracy Score for the Train Data is :" , (rf_train_accuracy)*100, "%")
print(" Random Forest Model Accuracy Score for the Test Data is :" ,(rf_test_accuracy)*100 , "%")
# Out:
#  Random Forest Model Accuracy Score for the Train Data is : 100.0 %
#  Random Forest Model Accuracy Score for the Test Data is : 99.22701383238405 %

# %% [markdown]
# ### 2. Logistic Regression

# %%
LR_classifier = LogisticRegression()
LR_classifier.fit(X_train_vectorized,Y_train)
# Out:
# LogisticRegression()

# %%
LR_train_predictions = LR_classifier.predict(X_train_vectorized)

# %%
LR_test_predictions = LR_classifier.predict(X_text_vectorized)

# %%
print(" Confusion Matrix For the Train Data: ")

confusion_matrix(Y_train,LR_train_predictions)
# Out:
#  Confusion Matrix For the Train Data:
# array([[15671,   156],
#        [  120, 13993]], dtype=int64)

# %%
print(" Confusion Matrix For the Test Data: ")

confusion_matrix(Y_test,LR_test_predictions)
# Out:
#  Confusion Matrix For the Test Data:
# array([[7524,  127],
#        [  84, 7013]], dtype=int64)

# %%
LR_train_accuracy = accuracy_score(Y_train,LR_train_predictions)
LR_test_accuracy = accuracy_score(Y_test,LR_test_predictions)

# %%
print("Logistic Regression Model Accuracy Score for the Train Data is :" ,(LR_train_accuracy)*100, "%")
print(" Logistic Regression Model Accuracy Score for the Test Data is :" ,(LR_test_accuracy)*100 , "%")
# Out:
# Logistic Regression Model Accuracy Score for the Train Data is : 99.07815631262525 %
#  Logistic Regression Model Accuracy Score for the Test Data is : 98.56929753186873 %

# %% [markdown]
# ### 3. Decision Tree

# %%
DT_classifier = DecisionTreeClassifier()
DT_classifier.fit(X_train_vectorized,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
DT_train_predictions = DT_classifier.predict(X_train_vectorized)

# %%
DT_test_predictions = DT_classifier.predict(X_text_vectorized)

# %%
print(" Confusion Matrix For the Train Data: ")

confusion_matrix(Y_train,DT_train_predictions)
# Out:
#  Confusion Matrix For the Train Data:
# array([[15827,     0],
#        [    0, 14113]], dtype=int64)

# %%
print(" Confusion Matrix For the Test Data: ")

confusion_matrix(Y_test,DT_test_predictions)
# Out:
#  Confusion Matrix For the Test Data:
# array([[7628,   23],
#        [  34, 7063]], dtype=int64)

# %%
DT_train_accuracy = accuracy_score(Y_train,DT_train_predictions)
DT_test_accuracy = accuracy_score(Y_test,DT_test_predictions)

# %%
print("Decision Tree Model Accuracy Score for the Train Data is :" ,(DT_train_accuracy)*100, "%")
print("Decision Tree Model Accuracy Score for the Test Data is :" , (DT_test_accuracy)*100, "%")
# Out:
# Decision Tree Model Accuracy Score for the Train Data is : 100.0 %
# Decision Tree Model Accuracy Score for the Test Data is : 99.61350691619202 %

# %% [markdown]
# ### 4. SVC

# %%
SVC_classifier = SVC(kernel ="linear")
SVC_classifier.fit(X_train_vectorized,Y_train)
# Out:
# SVC(kernel='linear')

# %%
SVC_train_predictions = SVC_classifier.predict(X_train_vectorized)

# %%
SVC_test_predictions = SVC_classifier.predict(X_text_vectorized)

# %%
print(" Confusion Matrix For the Train Data: ")

confusion_matrix(Y_train,SVC_train_predictions)
# Out:
#  Confusion Matrix For the Train Data:
# array([[15786,    41],
#        [   17, 14096]], dtype=int64)

# %%
print(" Confusion Matrix For the Test Data: ")

confusion_matrix(Y_test,SVC_test_predictions)
# Out:
#  Confusion Matrix For the Test Data:
# array([[7604,   47],
#        [  37, 7060]], dtype=int64)

# %%
SVC_train_accuracy = accuracy_score(Y_train,SVC_train_predictions)
SVC_test_accuracy =  accuracy_score(Y_test,SVC_test_predictions)

# %%
print("SVC Model Accuracy Score for the Train Data is :" ,(SVC_train_accuracy)*100, "%")
print("SVC Model Accuracy Score for the Test Data is :" ,(SVC_test_accuracy)*100, "%")
# Out:
# SVC Model Accuracy Score for the Train Data is : 99.8062792251169 %
# SVC Model Accuracy Score for the Test Data is : 99.43043124491456 %

# %% [markdown]
# ### 5. Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
NB_classifier = MultinomialNB()
NB_classifier.fit(X_train_vectorized,Y_train)
# Out:
# MultinomialNB()

# %%
NB_train_predictions = NB_classifier.predict(X_train_vectorized)

# %%
NB_test_predictions = NB_classifier.predict(X_text_vectorized)

# %%
print(" Confusion Matrix For the Train Data: ")

confusion_matrix(Y_train,NB_train_predictions)
# Out:
#  Confusion Matrix For the Train Data:
# array([[15127,   700],
#        [ 1003, 13110]], dtype=int64)

# %%
print(" Confusion Matrix For the Test Data: ")

confusion_matrix(Y_test,NB_test_predictions)
# Out:
#  Confusion Matrix For the Test Data:
# array([[7270,  381],
#        [ 561, 6536]], dtype=int64)

# %%
NB_train_accuracy = accuracy_score(Y_train,NB_train_predictions)
NB_test_accuracy = accuracy_score(Y_test,NB_test_predictions)

# %%
print("Naive Bayes Model Accuracy Score for the Train Data is :" ,(NB_train_accuracy)*100, "%")
print("Naive Bayes Model Accuracy Score for the Test Data is :" ,(NB_test_accuracy)*100 , "%")
# Out:
# Naive Bayes Model Accuracy Score for the Train Data is : 94.31195724782899 %
# Naive Bayes Model Accuracy Score for the Test Data is : 93.6126932465419 %

# %% [markdown]
# ### 6. Gradient Boosting Classifier

# %%
import xgboost as xgb

# %%
GB_classifier = xgb.XGBClassifier()
GB_classifier.fit(X_train_vectorized,Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
GB_train_predictions = GB_classifier.predict(X_train_vectorized)

# %%
GB_test_predictions = GB_classifier.predict(X_text_vectorized)

# %%
print(" Confusion Matrix For the Train Data: ")

confusion_matrix(Y_train,GB_train_predictions)
# Out:
#  Confusion Matrix For the Train Data:
# array([[15827,     0],
#        [    0, 14113]], dtype=int64)

# %%
print(" Confusion Matrix For the Test Data: ")

confusion_matrix(Y_test,GB_test_predictions)
# Out:
#  Confusion Matrix For the Test Data:
# array([[7631,   20],
#        [  19, 7078]], dtype=int64)

# %%
GB_train_accuracy = accuracy_score(Y_train,GB_train_predictions)
GB_test_accuracy = accuracy_score(Y_test,GB_test_predictions)

# %%
print("Gradient Boosting Model Accuracy Score for the Train Data is :" ,(GB_train_accuracy)*100, "%")
print("Gradient Boosting Model Accuracy Score for the Test Data is :" ,(GB_test_accuracy)*100 , "%")
# Out:
# Gradient Boosting Model Accuracy Score for the Train Data is : 100.0 %
# Gradient Boosting Model Accuracy Score for the Test Data is : 99.73555736371034 %

# %% [markdown]
# ### 7.  Ridge Classifier

# %%
from sklearn.linear_model import RidgeClassifier

# %%
RC_classifier = RidgeClassifier()
RC_classifier.fit(X_train_vectorized,Y_train)
# Out:
# RidgeClassifier()

# %%
RC_train_predictions = RC_classifier.predict(X_train_vectorized)

# %%
RC_test_predictions = RC_classifier.predict(X_text_vectorized)

# %%
print(" Confusion Matrix For the Train Data: ")

confusion_matrix(Y_train,RC_train_predictions)
# Out:
#  Confusion Matrix For the Train Data:
# array([[15791,    36],
#        [    8, 14105]], dtype=int64)

# %%
print(" Confusion Matrix For the Test Data: ")

confusion_matrix(Y_test,RC_test_predictions)
# Out:
#  Confusion Matrix For the Test Data:
# array([[7602,   49],
#        [  41, 7056]], dtype=int64)

# %%
RC_train_accuracy = accuracy_score(Y_train,RC_train_predictions)
RC_test_accuracy = accuracy_score(Y_test,RC_test_predictions)

# %%
print("Ridge Classifier Model Accuracy Score for the Train Data is :" ,(RC_train_accuracy)*100, "%")
print("Ridge Classifier Model Accuracy Score for the Test Data is :" , (RC_test_accuracy)*100, "%")
# Out:
# Ridge Classifier Model Accuracy Score for the Train Data is : 99.85303941215766 %
# Ridge Classifier Model Accuracy Score for the Test Data is : 99.38974776240846 %

# %% [markdown]
# ## Models Evaluation

# %%
from matplotlib import cm

model_names = ["Random Forest", "Logistic Regression", "Decision Tree", "SVC",
               "Naive Bayes", "Gradient Boosting", "Ridge Classifier"]
accuracy_scores = [rf_test_accuracy, LR_test_accuracy, DT_test_accuracy, SVC_test_accuracy, NB_test_accuracy, GB_test_accuracy,
                   RC_test_accuracy]

colors = cm.rainbow(np.linspace(0, 1, len(accuracy_scores)))

bar_positions = np.arange(len(accuracy_scores))
bar_width = 0.5
plt.figure(figsize =(8,4))
bars = plt.barh(bar_positions, accuracy_scores, height=bar_width, color=colors, linewidth=1.5)

plt.yticks(bar_positions, model_names)
plt.xlabel('Accuracy Score')
plt.ylabel('Models')
plt.title('Accuracy Scores of Different Models')

for bar, score in zip(bars, accuracy_scores):
    plt.text(bar.get_width()+0.15, bar.get_y() + bar.get_height()/2, f'{score:.2%}', va='center', ha='left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Final Model : Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
import xgboost as xgb

model = xgb.XGBClassifier()

param_grid = {
    'n_estimators': [150,200],
    'learning_rate': [0.1],
    'gamma':  [0.4],
    'min_child_weight': [4, 6],
     'max_depth': [6,8],
    'subsample': [0.8],
    'colsample_bytree': [0.7]
}
    

grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose = 10
)

grid_search.fit(X_train_vectorized, Y_train)

best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Hyperparameters:", best_params)
print("Best Accuracy Score:", best_score)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Best Hyperparameters: {'colsample_bytree': 0.7, 'gamma': 0.4, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 4, 'n_estimators': 200, 'subsample': 0.8}
# Best Accuracy Score: 0.9975617902471609

# %% [markdown]
# ## Final Model Building

# %%
final_model = xgb.XGBClassifier(n_estimators =200,
                               random_state = 10,
                               gamma=0.4,
                               n_jobs = -1,
                               min_child_weight = 4,
                               subsample = 0.8,
                               learning_rate = 0.2,
                               max_depth = 8,
                               colsample_bytree = 0.7,
                               eval_metric = 'error'
                               )
final_model.fit(X_train_vectorized,Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='error', feature_types=None,
#               gamma=0.4, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=4, missing=nan, monotone_constraints=None,
#               n_estimators=200, n_jobs=-1, num_parallel_tree=None,
#               predictor=None, random_state=10, ...)

# %%
final_train_predictions = final_model.predict(X_train_vectorized)

# %%
final_test_predictions = final_model.predict(X_text_vectorized)

# %%
final_train_accuracy = accuracy_score(Y_train,final_train_predictions)
final_test_accuracy = accuracy_score(Y_test,final_test_predictions)

# %%
print(" Final Model Accuracy Score for the Train Data is :" ,(final_train_accuracy)*100, "%")
print("Final Model Accuracy Score for the Test Data is :" ,(final_test_accuracy)*100 , "%")
# Out:
#  Final Model Accuracy Score for the Train Data is : 99.99665998663994 %
# Final Model Accuracy Score for the Test Data is : 99.76267968538107 %

# %% [markdown]
# ### Pipeline

# %%
import pickle

# %%
model_filename = 'News_Detection_Trained_Model.sav'
pickle.dump(final_model, open(model_filename, 'wb'))
vectorizer_filename = 'News_Detection_Tfidf_Vectorizer.sav'
pickle.dump(vectorizer, open(vectorizer_filename, 'wb'))

# %%
loaded_model = pickle.load(open('News_Detection_Trained_Model.sav','rb'))
loaded_vectorizer = pickle.load(open('News_Detection_Tfidf_Vectorizer.sav', 'rb'))

# %%
class Preprocessing:
    
    def __init__(self,data):
        self.data = data
    
    def text_preprocessing(self):
        pred_text = [self.data]
        preprocess_text = []
        lm = WordNetLemmatizer()
        stop_words = set(stopwords.words('english'))
        for text in pred_text:
            text = text.lower()
            text = re.sub('^a-zA-Z0-9',' ',text)
            text = re.sub('\[.*?\]','',text)
            text = re.sub("\\W"," ",text)
            text = re.sub('https?://\S+/www\.\S+','',text)
            text = re.sub("<.*?>+"," ",text)
            text = re.sub("[%s]" % re.escape(string.punctuation)," ",text)
            text = re.sub("\n"," ",text)
            text = re.sub("\w*\d\w*"," ",text)
            text = word_tokenize(text)
            text = [lm.lemmatize(x) for x in text if x not in stop_words]
            text = " ".join(text)
            preprocess_text.append(text)
        return preprocess_text

# %%
class Prediction:
    
    def __init__(self,pred_data,model):
        self.pred_data = pred_data
        self.model =  model
    
    def prediction_model(self):
        preprocess_data = Preprocessing(self.pred_data).text_preprocessing()
        data = vectorizer.transform(preprocess_data)
        prediction = self.model.predict(data)
        
        if prediction[0] == 0:
            return "The News is Fake."
        
        else:
            return "The News is Real."

# %%
user_data = true_df['text'][0]

# %%
Prediction(user_data,final_model).prediction_model()
# Out:
# 'The News is Real.'
